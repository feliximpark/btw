# %% [markdown]
# # Import libs und Daten

# %%
import pandas as pd
from datetime import datetime
import numpy as np
# XML-Lib laden
import xml.etree.ElementTree as ET
from datawrapper import Datawrapper
dw = Datawrapper(access_token = "79263c731ee5ea069033d6c0e7f62798e440a05b21a43a4b1f1ae765a7eab433")
from datetime import datetime
from datetime import date
import random
import os
import glob
os.getcwd()
os.chdir(r"C:\\Users\\c_knoop\\Desktop\\BTW_2021")

# %%
#url_xml = "./analyse_alt/rohdaten/wahl_gemeinden.xml"
url_xml = "./test_daten/F.210906.124700.GE.xml"
#url_xml = "./test_daten/F.210906.132800.WK.xml"
root = ET.parse(url_xml).getroot()
datenstand = "23.09.2021, 14:56 Uhr"

# %% [markdown]
# # historisches Wahlergebnis

# %% [markdown]
# ## DAten einlesen und auf notwendige Columns begrenzen

# %%
wahlergebnisse_2017 = pd.read_excel("./data/BW17_Ergebnisse_ORIGINALE.xlsx", sheet_name="BW17_Ergebnisse_GE_TG")

# %%
wahlergebnisse_2017.columns
# Out:
# Index(['Wahl', 'WK-Nr', 'WK-Name', 'Ebene', 'AGS', 'Ortname',
#        'Briefwahl_Sonderfall', 'Wahlberechtigte', 'Wähler', 'ungültige_1',
#        'gültige_1', 'CDU_1', 'DIE LINKE_1', 'SPD_1', 'AfD_1', 'GRÜNE_1',
#        'NPD_1', 'FDP_1', 'PIRATEN_1', 'FREIE WÄHLER_1', 'BüSo_1', 'MLPD_1',
#        'ÖDP_1', 'Die PARTEI_1', 'Bürgerkandidat_1', 'Der Auserwählte_1',
#        'Heimat Region Zwickau_1', 'Held_1', 'Hoyer_1',
#        'Internationalistisch. Bündnis_1', 'RINK_1', 'SGP_1',
#        'Wir sind LEIPZIGER_1', 'ungültige_2', 'gültige_2', 'CDU_2',
#        'DIE LINKE_2', 'SPD_2', 'AfD_2', 'GRÜNE_2', 'NPD_2', 'FDP_2',
#        'PIRATEN_2', 'FREIE WÄHLER_2', 'BüSo_2', 'MLPD_2', 'BGE_2', 'DiB_2',
#        'ÖDP_2', 'Die PARTEI_2', 'Tierschutzpartei_2', 'V-Partei³_2'],
#       dtype='object')

# %%
df_hist = wahlergebnisse_2017[['WK-Nr', 'WK-Name', 'AGS', 'Ortname',
       'Wahlberechtigte', 'Wähler', 'ungültige_1',
       'gültige_1', 'CDU_1', 'DIE LINKE_1', 'SPD_1', 'AfD_1', 'GRÜNE_1',
       'NPD_1', 'FDP_1', 'PIRATEN_1', 'FREIE WÄHLER_1', 'BüSo_1', 'MLPD_1',
       'ÖDP_1', 'Die PARTEI_1', 'Bürgerkandidat_1', 'Der Auserwählte_1',
       'Heimat Region Zwickau_1', 'Held_1', 'Hoyer_1',
       'Internationalistisch. Bündnis_1', 'RINK_1', 'SGP_1',
       'Wir sind LEIPZIGER_1', 'ungültige_2', 'gültige_2', 'CDU_2',
       'DIE LINKE_2', 'SPD_2', 'AfD_2', 'GRÜNE_2', 'NPD_2', 'FDP_2',
       'PIRATEN_2', 'FREIE WÄHLER_2', 'BüSo_2', 'MLPD_2', 'BGE_2', 'DiB_2',
       'ÖDP_2', 'Die PARTEI_2', 'Tierschutzpartei_2', 'V-Partei³_2']]

# %%
# richtige Formate verteilen
df_hist = df_hist.replace("x", "0")
# using dictionary to convert specific columns
convert_dict = {'WK-Nr': str,
                'AGS': str, 
                "AfD_1": int, 
                "NPD_1": int, 
                "PIRATEN_1": int, 
                "BüSo_1": int,
                "MLPD_1": int, 
                "ÖDP_1": int, 
                "Die PARTEI_1": int, 
                "Bürgerkandidat_1": int, 
                "Der Auserwählte_1": int, 
                "Heimat Region Zwickau_1": int, 
                "Held_1": int, 
                "Hoyer_1": int, 
                "Internationalistisch. Bündnis_1": int, 
                "RINK_1": int, 
                "SGP_1": int, 
                "Wir sind LEIPZIGER_1": int, 
                "FREIE WÄHLER_1": int
               }
 
    
    
df_hist = df_hist.astype(convert_dict)

# rename columns
df_hist.rename(columns={"WK-Nr": "KreisId", "WK-Name":"KreisName", "Ortname": "Ort"}, inplace=True)

# %%
df_hist.columns
# Out:
# Index(['KreisId', 'KreisName', 'AGS', 'Ort', 'Wahlberechtigte', 'Wähler',
#        'ungültige_1', 'gültige_1', 'CDU_1', 'DIE LINKE_1', 'SPD_1', 'AfD_1',
#        'GRÜNE_1', 'NPD_1', 'FDP_1', 'PIRATEN_1', 'FREIE WÄHLER_1', 'BüSo_1',
#        'MLPD_1', 'ÖDP_1', 'Die PARTEI_1', 'Bürgerkandidat_1',
#        'Der Auserwählte_1', 'Heimat Region Zwickau_1', 'Held_1', 'Hoyer_1',
#        'Internationalistisch. Bündnis_1', 'RINK_1', 'SGP_1',
#        'Wir sind LEIPZIGER_1', 'ungültige_2', 'gültige_2', 'CDU_2',
#        'DIE LINKE_2', 'SPD_2', 'AfD_2', 'GRÜNE_2', 'NPD_2', 'FDP_2',
#        'PIRATEN_2', 'FREIE WÄHLER_2', 'BüSo_2', 'MLPD_2', 'BGE_2', 'DiB_2',
#        'ÖDP_2', 'Die PARTEI_2', 'Tierschutzpartei_2', 'V-Partei³_2'],
#       dtype='object')

# %% [markdown]
# ## Städte zusammenführen

# %%
# Städte zusammenfassen
# Stadtname und übergreifende AGS
city_dict = {"Leipzig":"14713000", "Dresden":"14612000"}

# Ergebnisliste

def group_cities_results(df, city_dict): 
   
    list_cities = list(city_dict.keys())
    df_final = df[~df["Ort"].str.contains("|".join(list_cities))]
    
    print(df_final.shape)
    for city in city_dict:
        df_ = df[df["Ort"].str.contains(city)]
        
        # Ort und AGS vereinheitlichen
        df_["Ort"] = city
        df_["AGS"] = city_dict[city]
        df_["KreisId"] = df_["Ort"].map(lambda x: "152/153" if x == "Leipzig" else "159/160")
        df_["KreisName"] = df_["Ort"].map(lambda x: "Leipzig I/II" if x == "Leipzig" else "Dresden I/DD-Bautzen II")
        # über neuen, einheitlichen Ortsnamen gruppieren
        df_group = df_.groupby(['KreisId', 'KreisName', 'AGS', 'Ort',], as_index=False).sum()
       
        # Daten wieder zusammenführen
        df_final = df_final.append(df_group)
       
    
    return df_final
    
df_2017 = group_cities_results(df_hist, city_dict)
# Out:
# (420, 49)
# <ipython-input-109-3cc2447c6df1>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_["Ort"] = city
# <ipython-input-109-3cc2447c6df1>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_["AGS"] = city_dict[city]
# <ipython-input-109-3cc2447c6df1>:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_["KreisId"] = df_["Ort"].map(lambda x: "152/153" if x == "Leipzig" else "159/160")
# <ipython-input-109-3cc2447c6df1>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_["KreisName"] = df_["Ort"].map(lambda x: "Leipzig I/II" if x == "Leipzig" else "Dresden I/DD-Bautzen II")

# %%
df_2017[df_2017["Ort"].str.contains("Leipzig")]
# Out:
#    KreisId     KreisName       AGS      Ort  Wahlberechtigte  Wähler  \
# 0  152/153  Leipzig I/II  14713000  Leipzig           448372  336605
#
#    ungültige_1  gültige_1  CDU_1  DIE LINKE_1  ...  PIRATEN_2  FREIE WÄHLER_2  \
# 0         3188     333417  86697        75080  ...       1817            2745
#
#    BüSo_2  MLPD_2  BGE_2  DiB_2  ÖDP_2  Die PARTEI_2  Tierschutzpartei_2  \
# 0     440     505   2051   1654    706          7408                5432
#
#    V-Partei³_2
# 0          832
#
# [1 rows x 49 columns]

# %% [markdown]
# ## Historische Daten Erststimme vorbereiten

# %%
# hier geht es darum, den stärksten Kandidaten für die Gemeinde 2017 herauszusuchen... ist optional, lassen wir erstmal

# %%
def create_hist_erststimme(df): 
    
    all_kreis_id = df.KreisId.unique(): 
    


df_2017_es = create_hist_erststimme(df_2017)

# %% [markdown]
# ## Historische Daten Zweitstimme

# %% [markdown]
# Hier benötige ich die **Wahlbeteiligung und die Prozentzahl pro Partei** bzw. sonstige

# %%
def create_hist_zweitstimme(df):
    
    # neues Dataframe für historische Zweitstimmen
    cols = ["AGS", "Wahlbeteiligung", "2017_AfD_%", "2017_CDU_%", "2017_LINKE_%","2017_SPD_%", \
           "2017_GRÜNE_%", "2017_FDP_%", "2017_sonstige_%"]
    
    new_df = pd.DataFrame(columns=cols)
    
    
    df = df[['KreisId', 'KreisName', 'AGS', 'Ort', 'Wahlberechtigte', 'Wähler', \
            'gültige_2', 'CDU_2','DIE LINKE_2', 'SPD_2', 'AfD_2', 'GRÜNE_2', 'NPD_2', 'FDP_2',\
       'PIRATEN_2', 'FREIE WÄHLER_2', 'BüSo_2', 'MLPD_2', 'BGE_2', 'DiB_2',\
       'ÖDP_2', 'Die PARTEI_2', 'Tierschutzpartei_2', 'V-Partei³_2']]
    
    all_ags = df.AGS.unique()
        
    for ags in all_ags: 
        df_ = df[df.AGS==ags]
        
        wbt = round(df_["Wähler"] / df_["Wahlberechtigte"]  * 100, 1).item()
        afd = round(df_.AfD_2 / df_.gültige_2 * 100, 1).item()
        cdu = round(df_.CDU_2 / df_.gültige_2 * 100, 1).item()
        linke = round(df_["DIE LINKE_2"] / df_.gültige_2 * 100, 1).item()
        spd = round(df_.SPD_2 / df_.gültige_2 * 100, 1).item()
        grüne = round(df_.GRÜNE_2 / df_.gültige_2 * 100, 1).item()
        fdp = round(df_.FDP_2 / df_.gültige_2 * 100, 1).item()
        sonstige_stimmen = df_.gültige_2.item() - (df_.AfD_2 + df_.CDU_2 +df_["DIE LINKE_2"] + df_.SPD_2 + df_.GRÜNE_2 + df_.FDP_2).item()
        sonstige = round(sonstige_stimmen/df_.gültige_2*100,1).item()
        
        ser_data = [ags, wbt, afd, cdu, linke, spd, grüne, fdp, sonstige]
        new_ser = pd.Series(ser_data, index=cols)
        
        new_df = new_df.append(new_ser, ignore_index=True)
    
    return new_df
        


df_2017_zw = create_hist_zweitstimme(df_2017)

# %%
df_2017_zw
# Out:
#           AGS  Wahlbeteiligung  2017_AfD_%  2017_CDU_%  2017_LINKE_%  \
# 0    14730010             58.5        31.2        28.4          14.5
# 1    14730020             71.3        22.9        30.4          15.8
# 2    14730030             78.1        28.4        30.7          13.8
# 3    14730045             72.2        31.8        28.6          12.6
# 4    14730050             79.7        32.4        31.0          13.0
# ..        ...              ...         ...         ...           ...
# 417  14523440             60.5        26.3        30.5          16.7
# 418  14523450             78.8        24.7        33.8          14.2
# 419  14523460             71.1        26.7        35.6          13.1
# 420  14713000             75.1        18.3        22.7          21.0
# 421  14612000             79.1        22.5        23.5          17.6
#
#      2017_SPD_%  2017_GRÜNE_%  2017_FDP_%  2017_sonstige_%
# 0          10.4           1.1         7.9              6.5
# 1          13.8           3.1         8.6              5.4
# 2          11.9           1.7         8.0              5.7
# 3          11.9           2.1         6.7              6.3
# 4           8.4           1.9         7.3              6.1
# ..          ...           ...         ...              ...
# 417        11.3           2.5         6.0              6.8
# 418        10.4           3.5         7.7              5.7
# 419         9.1           2.5         7.9              5.2
# 420        13.0           8.8         8.5              7.6
# 421        10.2           8.7         9.9              7.5
#
# [422 rows x 9 columns]

# %% [markdown]
# # Herauslesen Daten Dataframe long

# %%
#HELPER
# Ordnet die Beschreibung des Tags <Gruppenergebnis> einer Klarbzeichung zu
# diese Beschreibung ist unter dem Attribut Position abgespeichert

# Check ob sich in einem String eine Nummer befindet
def has_numbers(inputString):
    return any(char.isdigit() for char in inputString)

# %%
# Dict Parteien

# %%
# Offizielle Listennummer mit Parteiname BTW 2021
parteien_dict = {"1":"AfD", "2":"CDU", "3":"LINKE", "4":"SPD", "5":"FDP", "6":"GRÜNE", \
                # kleinere Parteien (sonstige)
                "7":"Tierschutzpartei", "8":"Die PARTEI", "9":"NPD", "10":"FREIE WÄHLER", \
                 "11":"PIRATEN", "12":"ÖDP", "13":"V-Partei³", "14":"MLPD", "15":"dieBasis", 
                 "16": "Bündnis C", "17": "III. Weg", "18":"DKP", "19":"Die Humanisten", \
                 "20":"Gesundheitsforschung", "21":"Team Todenhöfer", "22":"Volt", \
                 # kleinere Parteien ohne Landesliste
                 "23": "ASMUSfddB", "24":"AufrechterDemokrat", "25":"Brähmig", "26":"BüSo", \
                 "27":"Daniel Richter", "28":"Direktkandidat Daniel Zimmet", "29":"Direktkandidat Frank Hannig", \
                 "30": "DK Schöllner", "31":"Ein Leipziger für Leipzig", "32":"#KLIMAfirst", \
                 "33": "Internationalistisches Bündnis", "34": "Internationalistisches Bündnis", \
                 "35": "Internationalistisches Bündnis", "36":"Ischgl", "37":"KARLKOMMT", \
                 "38": "LKR", "39": "Marcus Fuchs - Querdenken 351", "40":"Queck", "41":"REICHEL",\
                 "42":"Röhder", "43":"UNO - Menschrecht - FRIEDEN für Alle", "44":"WIR sind LEIPZIGER", \
                 "45":"www.zeitkaufhaus.de Martin Bayer", \
                 # Bezeichner für gültige und ungültige Stimmen
                "GUE": "gültige Stimmen", "UNG": "Ungültige Stimmen"

                }

# %%
# Listennummer Parteien LTW 2019
lt_parties_dict = {
    "1":"CDU", "2":"LINKE", "3":"SPD", "4":"AfD", "5": "GRÜNE", "6":"NPD", "7":"FDP", \
    "8":"FREIE WÄHLER", "9":"Tierschutzpartei", "10":"PIRATEN", "11":"DIE PARTEI", "12":"BüSo", \
    "13":"ADPM", "14":"Blaue", "15":"KPD", "16":"ÖDP", "17":"Humanisten", "18":"PDV", \
    "19":"Gesundheitsforschung", "20":"andere1", "21":"andere2", \
    # Bezeichner für gültige und ungültige Stimmen
    "GUE": "gültige Stimmen", "UNG": "Ungültige Stimmen"
    
}

# %%
# jedes elem in root ist der Tag <Gebietsergebnis>, in dem immer eine komplette Gemeinde steckt. 
def read_xml(root):
    
    # Variablen in Datensatz
    erststimmen = "DIREKT"
    zweitstimmen = "LISTE"


    
    # zwei Dataframes werden erstellt, eins für die Ergebnisse der Parteien, 
    # ein anderes für Wahlstatistiken etc. 
    
    # DF Ergebnisse
    cols_result = ["AGS", "KreisId", "Ort", "Partei", "ParteiId", "Stimmart", "Stimmen", "Anteil"]
    df_results = pd.DataFrame(columns=cols_result)
    
    # DF Statistiken
    col_stats = ["AGS", "Ort", "WKNr", "Statistik", "Stimmen", "Anteil"]
    df_stats = pd.DataFrame(columns=col_stats)
    
    # Durchlauf durch alle <Gruppenergebnis>, sammeln der Gemeindedaten
    for elem in root: 
        ags = elem.attrib.get("GemNr")
        name = elem.attrib.get("GemName") 
        wk_nr = elem.attrib.get("KreisNr")
        # Unterpunkt ist <Gruppenergebnis>, hier findet sich unter "Position" die Beschreibung des jew. Datensatzes
        for sub in elem: 
            position = sub.attrib.get("Position")
            
            # Check ob position eine Nummer ist - dann handelt es sich nämlich um ein Partei-Stimmergebnis
            # dann wird das result-Dataframe befüllt
            if (has_numbers(position)) | (position == "UNG") | (position == "GUE"): 
                partei = parteien_dict[position]
                for node in sub: 
                    kind_of_votes = node.attrib.get("Stimmart")
                    if kind_of_votes == erststimmen: 
                        stimmart = "Erststimme"
                    else: 
                        stimmart = "Zweitstimme"
                    count_votes = node.attrib.get("Stimmen")
                    votes_share = node.attrib.get("Anteil")
                    ser_results = pd.Series([ags, wk_nr, name, partei, position, stimmart, count_votes, votes_share], index=cols_result)
                    df_results = df_results.append(ser_results, ignore_index=True)
            
            # wenn Buchstaben-Kennung wird das statistische Dataframe befüllt
            else:
                
                info_node = sub[0]
                stimmen = info_node.attrib.get("Stimmen")
                anteil = info_node.attrib.get("Anteil")
                
                if position == "WB": 
                    statistik = "Wahlberechtigte"
                    anteil = "100"
                elif position == "WAE":
                    statistik = "Wähler"
                else: 
                    print("Fehler")
               
                ser_stats = pd.Series([ags, name, wk_nr, statistik, stimmen, anteil], index=col_stats)
                df_stats = df_stats.append(ser_stats, ignore_index=True)
        
    return df_results, df_stats
                    
                    
            #if position
            
           

            
            
            
df_results_abfrage, df_daten_abfrage = read_xml(root)

# %%
df_results_abfrage.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15419 entries, 0 to 15418
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   AGS       15419 non-null  object
#  1   KreisId   15419 non-null  object
#  2   Ort       15419 non-null  object
#  3   Partei    15419 non-null  object
#  4   ParteiId  15419 non-null  object
#  5   Stimmart  15419 non-null  object
#  6   Stimmen   15419 non-null  object
#  7   Anteil    15419 non-null  object
# dtypes: object(8)
# memory usage: 963.8+ KB

# %% [markdown]
# ## richtige Datentypen vergeben

# %%
# richtige Datentypen vergeben
df_results_abfrage["Stimmen"] = df_results_abfrage["Stimmen"].astype(int)
df_results_abfrage["Anteil"] = df_results_abfrage["Anteil"].astype(float)
df_results_abfrage["KreisId"] = df_results_abfrage["KreisId"].astype(str)
df_results_abfrage["ParteiId"] = df_results_abfrage["ParteiId"].astype(str)

df_daten_abfrage["Stimmen"] = df_daten_abfrage["Stimmen"].astype(int)
df_daten_abfrage["Anteil"] = df_daten_abfrage["Anteil"].astype(float)

# %% [markdown]
# ## Aus mehreren Stadt-Ergebnissen ein Ergebnis und einen Datensatz für jede Großstadt

# %%
# Stadtname und übergreifende AGS
city_dict = {"Leipzig":"14713000", "Dresden":"14612000"}

# Ergebnisliste

def group_cities_results(df, city_dict): 
    df_final = df.copy()
    
    for city in city_dict:
        df_ = df[df["Ort"].str.contains(city)]
        # Ort und AGS vereinheitlichen
        df_["Ort"] = city
        df_["AGS"] = city_dict[city]
        
        # über neuen, einheitlichen Ortsnamen gruppieren
        df_group = df_.groupby(["AGS", "Ort", "Partei", "Stimmart"], as_index=False).agg({"Stimmen":"sum"})
        
        
        # Anteile der Parteien neu ausrechnen
        # Erststimmen
        df_group.loc[df_group["Stimmart"]=="Erststimme", "Anteil"] = round(df_group.loc[df_group["Stimmart"]=="Erststimme"]["Stimmen"] / \
                                                    df_group.loc[(df_group["Stimmart"]=="Erststimme") & \
                                                             (df_group["Partei"]=="gültige Stimmen")]["Stimmen"]\
                                                                       .item() * 100,1)
        #Zweitstimmen
        df_group.loc[df_group["Stimmart"]=="Zweitstimme", "Anteil"] = round(df_group.loc[df_group["Stimmart"]=="Zweitstimme"]["Stimmen"] / \
                                                    df_group.loc[(df_group["Stimmart"]=="Zweitstimme") & \
                                                             (df_group["Partei"]=="gültige Stimmen")]["Stimmen"]\
                                                                       .item() * 100,1)
        
        # gültige Erststimmen
        df_group.loc[(df_group["Stimmart"]=="Erststimme") & (df_group["Partei"]=="gültige Stimmen"), "Anteil"] = round(\
            df_group.loc[(df_group["Stimmart"]=="Erststimme") & (df_group["Partei"]=="gültige Stimmen")]["Stimmen"].item() /\
            (df_group.loc[(df_group["Stimmart"]=="Erststimme") & (df_group["Partei"]=="gültige Stimmen")]["Stimmen"].item() + \
            df_group.loc[(df_group["Stimmart"]=="Erststimme") & (df_group["Partei"]=="Ungültige Stimmen")]["Stimmen"].item()) \
            * 100, 1) 
        # gültige Zweitstimmen
        df_group.loc[(df_group["Stimmart"]=="Zweitstimme") & (df_group["Partei"]=="gültige Stimmen"), "Anteil"] = round(\
            df_group.loc[(df_group["Stimmart"]=="Zweitstimme") & (df_group["Partei"]=="gültige Stimmen")]["Stimmen"].item() /\
            (df_group.loc[(df_group["Stimmart"]=="Zweitstimme") & (df_group["Partei"]=="gültige Stimmen")]["Stimmen"].item() + \
            df_group.loc[(df_group["Stimmart"]=="Zweitstimme") & (df_group["Partei"]=="Ungültige Stimmen")]["Stimmen"].item()) \
            * 100, 1) 
        
        df_final = df_final[~df_final["Ort"].str.contains(city)]
        df_final = df_final.append(df_group)
    
    return df_final
    
df_ergebnisse = group_cities_results(df_results_abfrage, city_dict)
# Out:
# <ipython-input-263-01650609b406>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_["Ort"] = city
# <ipython-input-263-01650609b406>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_["AGS"] = city_dict[city]

# %%
df_ergebnisse
# Out:
#          AGS KreisId      Ort             Partei ParteiId     Stimmart  \
# 0   14730010     151  Arzberg  Ungültige Stimmen      UNG   Erststimme
# 1   14730010     151  Arzberg  Ungültige Stimmen      UNG  Zweitstimme
# 2   14730010     151  Arzberg    gültige Stimmen      GUE   Erststimme
# 3   14730010     151  Arzberg    gültige Stimmen      GUE  Zweitstimme
# 4   14730010     151  Arzberg                AfD        1   Erststimme
# ..       ...     ...      ...                ...      ...          ...
# 39  14612000     NaN  Dresden           dieBasis      NaN  Zweitstimme
# 40  14612000     NaN  Dresden    gültige Stimmen      NaN   Erststimme
# 41  14612000     NaN  Dresden    gültige Stimmen      NaN  Zweitstimme
# 42  14612000     NaN  Dresden                ÖDP      NaN   Erststimme
# 43  14612000     NaN  Dresden                ÖDP      NaN  Zweitstimme
#
#     Stimmen  Anteil
# 0         7     0.9
# 1         8     1.0
# 2       793    99.1
# 3       792    99.0
# 4       198    25.0
# ..      ...     ...
# 39       33     0.0
# 40   263882    99.0
# 41   263909    99.0
# 42     2272     0.9
# 43      912     0.3
#
# [15341 rows x 8 columns]

# %%
# Datenliste

def group_cities_data(df, city_dict): 
    # Kopie anfertigen, aus der später die einzelnen Datensätze entfernt und angehangen werden. 
    df_final = df.copy()
    
    for city in city_dict:
        df_ = df[df["Ort"].str.contains(city)]
        # Ort und AGS vereinheitlichen
        df_["Ort"] = city
        df_["AGS"] = city_dict[city]
        # Wahlkreis-Nummern herausfinden
        min_wk = df_["WKNr"].astype(int).min()
        max_wk =  df_["WKNr"].astype(int).max()
        df_["WKNr"] = f"{min_wk}-{max_wk}"
        
        # über neuen, einheitlichen Ortsnamen gruppieren
        df_group = df_.groupby(["AGS", "Ort", "WKNr", "Statistik"], as_index=False).agg({"Stimmen":"sum"})
        
        
        # Anteile der Parteien neu ausrechnen
        # Erststimmen
        df_group.loc[df_group["Statistik"]=="Wahlberechtigte", "Anteil"] = 100
        #Zweitstimmen
        df_group.loc[df_group["Statistik"]=="Wähler", "Anteil"] = round(df_group.loc[df_group["Statistik"]=="Wähler"]["Stimmen"] / \
                                                    df_group.loc[df_group["Statistik"]=="Wahlberechtigte"]["Stimmen"].item() * 100,1)
        
       
        df_final = df_final[~df_final["Ort"].str.contains(city)]
        df_final = df_final.append(df_group)
    
    return df_final

df_daten = group_cities_data(df_daten_abfrage, city_dict)
# Out:
# <ipython-input-156-367b36a6cd5c>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_["Ort"] = city
# <ipython-input-156-367b36a6cd5c>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_["AGS"] = city_dict[city]
# <ipython-input-156-367b36a6cd5c>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_["WKNr"] = f"{min_wk}-{max_wk}"

# %% [markdown]
# ## Daten in Erst- und Zweitstimme teilen

# %%
# Daten Ergebnisse aufsplitten und zusätzlich eine "andere Parteien"-Version ausspielen

def split_up_data(df_ergebnisse): 
    df_ergebnisse_es = df_ergebnisse[df_ergebnisse["Stimmart"]=="Erststimme"]
    df_ergebnisse_zs = df_ergebnisse[df_ergebnisse["Stimmart"]=="Zweitstimme"]
    return df_ergebnisse_es, df_ergebnisse_zs

df_es, df_zs = split_up_data(df_ergebnisse)

# %% [markdown]
# # ZWEITSTIMME

# %% [markdown]
# ## "Andere Parteien" einrichten

# %%
def reduce_number_of_parties(df): 
    liste_standing_terms = ["Ungültige Stimmen", "gültige Stimmen", "CDU", "LINKE", \
                           "SPD", "AfD", "GRÜNE", "FDP"]


    sti = df.Stimmart.iloc[0]

    df_ = df[~df["Partei"].isin(liste_standing_terms)]
    df_rest = df[df["Partei"].isin(liste_standing_terms)]
    df_flat = df_.groupby(["AGS", "Ort"], as_index=False).agg({"Stimmen":"sum", "Anteil":"sum"})




    if sti == "Erststimme": 
        df_flat["Stimmart"] = "Erststimme"
        df_flat["Partei"] = "andere Parteien"
        df_flat = df_flat[['AGS', 'Ort', 'Partei', 'Stimmart', 'Stimmen', 'Anteil']]
        df_flat = df_flat.append(df_rest)
    elif sti == "Zweitstimme": 
        df_flat["Stimmart"] = "Zweitstimmen"
        df_flat["Partei"] = "andere Parteien"
        df_flat = df_flat[['AGS', 'Ort', 'Partei', 'Stimmart', 'Stimmen', 'Anteil']]
        df_flat = df_flat.append(df_rest)
    else: 
        print('Fehler')




    return df_flat

    
    
    
    
df_zs_flat = reduce_number_of_parties(df_zs)

# %% [markdown]
# ## Daten auf wide umstellen / Prefix vergeben

# %%
def results_long_to_wide(df_ergebnisse ,prefix="2_"): 
    df_results_wide = pd.pivot(df_ergebnisse, index=["AGS", "Ort"], columns="Partei", values=["Stimmen", "Anteil"])\
        .reset_index().fillna("0")
   
    # Multi-Index-Columns werden aufgelöst
    df_results_wide.columns = [" ".join(col).strip() for col in df_results_wide.columns.values]
   
    
    # Columns erhalten ein Präfix
    # Präfixhinzufügen
    df_results_wide = df_results_wide.add_prefix(prefix)
   

    # Columns AgS und Ort Prefix entfernen
    df_results_wide.rename(columns={"1_AGS":"AGS", "1_Ort":"Ort"}, inplace=True)
    df_results_wide.rename(columns={"2_AGS":"AGS", "2_Ort":"Ort"}, inplace=True)
   

    df_results_wide.fillna(0)
    
    # convert Stimmen from float to int
    filter_stimmen = [col for col in df_results_wide if (col.startswith("1_Stimmen")) | (col.startswith("2_Stimmen")) ]
    df_results_wide[filter_stimmen] = df_results_wide[filter_stimmen].astype(int)
    
    return df_results_wide
 
df_results = results_long_to_wide(df_zs_flat)

# %% [markdown]
# ## Korrekter Anteil für "andere Parteien" berechnen

# %%
def correct_anteil_andere_parteien(df_re):
    
    # erst Anteil für Erststimmen andere Parteinen
    try: 
        df_re["1_Anteil andere Parteien"] = round(df_re["1_Stimmen andere Parteien"] / df_re["1_Stimmen gültige Stimmen"] * 100,1)
        df_re["1_Anteil andere Parteien"] = df_re["1_Anteil andere Parteien"].astype(float)
        
    except:
        try:
            
            df_re["2_Anteil andere Parteien"] = round(df_re["2_Stimmen andere Parteien"] / df_re["2_Stimmen gültige Stimmen"] * 100,1)
            df_re["2_Anteil andere Parteien"] = df_re["2_Anteil andere Parteien"].astype(float)
    
        except: 
            print("Fehler!")
   

    return df_re

df_results_correct = correct_anteil_andere_parteien(df_results)

# %%
df_results_correct.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 419 entries, 0 to 418
# Data columns (total 20 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   AGS                          419 non-null    object
#  1   Ort                          419 non-null    object
#  2   2_Stimmen AfD                419 non-null    int32
#  3   2_Stimmen CDU                419 non-null    int32
#  4   2_Stimmen FDP                419 non-null    int32
#  5   2_Stimmen GRÜNE              419 non-null    int32
#  6   2_Stimmen LINKE              419 non-null    int32
#  7   2_Stimmen SPD                419 non-null    int32
#  8   2_Stimmen Ungültige Stimmen  419 non-null    int32
#  9   2_Stimmen andere Parteien    419 non-null    int32
#  10  2_Stimmen gültige Stimmen    419 non-null    int32
#  11  2_Anteil AfD                 419 non-null    float64
#  12  2_Anteil CDU                 419 non-null    float64
#  13  2_Anteil FDP                 419 non-null    float64
#  14  2_Anteil GRÜNE               419 non-null    float64
#  15  2_Anteil LINKE               419 non-null    float64
#  16  2_Anteil SPD                 419 non-null    float64
#  17  2_Anteil Ungültige Stimmen   419 non-null    float64
#  18  2_Anteil andere Parteien     419 non-null    float64
#  19  2_Anteil gültige Stimmen     419 non-null    float64
# dtypes: float64(9), int32(9), object(2)
# memory usage: 50.9+ KB

# %% [markdown]
# ## Statistik-DAten auf wide stellen, Ergebnisdaten mit Statistik-Daten verbinden

# %%
def statistic_long_to_wide(df): 
    
    df_wide = pd.pivot(df, index=["AGS", "Ort" ,"WKNr"], columns="Statistik", values=["Stimmen", "Anteil"])\
        .reset_index().fillna("0")
    # Multi-Index-Columns werden aufgelöst
    df_wide.columns = [" ".join(col).strip() for col in df_wide.columns.values]
    df_wide[["Stimmen Wahlberechtigte", "Stimmen Wähler"]] = \
        df_wide[["Stimmen Wahlberechtigte", "Stimmen Wähler"]].astype(int)
    
    return df_wide
    
df_daten_wide = statistic_long_to_wide(df_daten)

# %% [markdown]
# ## Ergebnisse und Statistik mergen

# %%
def merge_results_and_stats(df_results, df_stats): 
    # Results mit Statistik mergen
    df_all_merge = pd.merge(df_results, df_stats, on=["AGS", "Ort"])
    return df_all_merge

df_final = merge_results_and_stats(df_results_correct, df_daten_wide)

# %%
df_final
# Out:
#           AGS                       Ort  2_Stimmen AfD  2_Stimmen CDU  \
# 0    14511000           Chemnitz, Stadt          32715          16357
# 1    14521010                  Amtsberg            526            259
# 2    14521020  Annaberg-Buchholz, Stadt           3067           1533
# 3    14521035    Aue-Bad Schlema, Stadt           3032           1512
# 4    14521040                  Auerbach            424            220
# ..        ...                       ...            ...            ...
# 414  14730310             Torgau, Stadt           2669           1342
# 415  14730320                   Trossin            165             84
# 416  14730330                 Wermsdorf            645            323
# 417  14730340                  Wiedemar            780            384
# 418  14730360                Zschepplin            388            190
#
#      2_Stimmen FDP  2_Stimmen GRÜNE  2_Stimmen LINKE  2_Stimmen SPD  \
# 0            10936             6107            16381          32674
# 1              188               67              266            530
# 2              789              345             1523           3052
# 3              759              240             1508           2989
# 4              110               26              216            445
# ..             ...              ...              ...            ...
# 414            786              266             1365           2677
# 415             53               22               84            164
# 416            171               78              323            649
# 417            238               59              390            759
# 418            123               54              198            386
#
#      2_Stimmen Ungültige Stimmen  2_Stimmen andere Parteien  ...  \
# 0                           1286                      15536  ...
# 1                             26                        269  ...
# 2                            110                       1946  ...
# 3                            134                       2023  ...
# 4                             14                        286  ...
# ..                           ...                        ...  ...
# 414                          119                       1645  ...
# 415                            8                         92  ...
# 416                           31                        391  ...
# 417                           30                        483  ...
# 418                           15                        220  ...
#
#      2_Anteil LINKE  2_Anteil SPD  2_Anteil Ungültige Stimmen  \
# 0              12.5          25.0                         1.0
# 1              12.6          25.2                         1.2
# 2              12.4          24.9                         0.9
# 3              12.5          24.8                         1.1
# 4              12.5          25.8                         0.8
# ..              ...           ...                         ...
# 414            12.7          24.9                         1.1
# 415            12.7          24.7                         1.2
# 416            12.5          25.2                         1.2
# 417            12.6          24.5                         1.0
# 418            12.7          24.8                         1.0
#
#      2_Anteil andere Parteien  2_Anteil gültige Stimmen  WKNr  \
# 0                        11.9                      99.0   162
# 1                        12.8                      98.8   164
# 2                        15.9                      99.1   164
# 3                        16.8                      98.9   164
# 4                        16.6                      99.2   163
# ..                        ...                       ...   ...
# 414                      15.3                      98.9   151
# 415                      13.9                      98.8   151
# 416                      15.2                      98.8   151
# 417                      15.6                      99.0   151
# 418                      14.1                      99.0   151
#
#      Stimmen Wahlberechtigte  Stimmen Wähler  Anteil Wahlberechtigte  \
# 0                     189120          131992                   100.0
# 1                       3009            2131                   100.0
# 2                      16157           12365                   100.0
# 3                      16740           12197                   100.0
# 4                       2050            1741                   100.0
# ..                       ...             ...                     ...
# 414                    15594           10869                   100.0
# 415                     1061             672                   100.0
# 416                     4350            2611                   100.0
# 417                     4525            3123                   100.0
# 418                     2331            1574                   100.0
#
#      Anteil Wähler
# 0             69.8
# 1             70.8
# 2             76.5
# 3             72.9
# 4             84.9
# ..             ...
# 414           69.7
# 415           63.3
# 416           60.0
# 417           69.0
# 418           67.5
#
# [419 rows x 25 columns]

# %% [markdown]
# ## Historisches Ergebnis mit einrechnen

# %%
dfh = wahlergebnisse_2021.copy()
dfh["AGS"]= dfh["AGS"].astype(str)
dfh = dfh.loc[:, dfh.columns != "Ort"]
dfh[dfh["AGS"].str.contains("14612000")]
# Out:
#           AGS  2017_AfD_%  2017_CDU_%  2017_LINKE_%  2017_SPD_%  2017_FDP_%  \
# 418  14612000        22.5        23.5          17.6        10.2         9.9
#
#      2017_GRÜNE_%  2017_andere_%
# 418           8.7            7.5

# %%
df_final = df_final.merge(dfh, on="AGS")

# %%
wahlergebnisse_2021
# Out:
#           AGS                      Ort  2017_AfD_%  2017_CDU_%  2017_LINKE_%  \
# 0    14730010                  Arzberg        31.2        28.4          14.5
# 1    14730020         Bad Düben, Stadt        22.9        30.4          15.8
# 2    14730030                 Beilrode        28.4        30.7          13.8
# 3    14730045  Belgern-Schildau, Stadt        31.8        28.6          12.6
# 4    14730050                Cavertitz        32.4        31.0          13.0
# ..        ...                      ...         ...         ...           ...
# 416  14523450               Weischlitz        24.7        33.8          14.2
# 417  14523460                    Werda        26.7        35.6          13.1
# 418  14612000                  Dresden        22.5        23.5          17.6
# 419  14713000                  Leipzig        18.3        22.7          21.0
# 420  14521035          Aue-Bad Schlema        28.1        27.9          17.3
#
#      2017_SPD_%  2017_FDP_%  2017_GRÜNE_%  2017_andere_%
# 0          10.4         7.9           1.1            6.5
# 1          13.8         8.6           3.1            5.4
# 2          11.9         8.0           1.7            5.7
# 3          11.9         6.7           2.1            6.3
# 4           8.4         7.3           1.9            6.1
# ..          ...         ...           ...            ...
# 416        10.4         7.7           3.5            5.7
# 417         9.1         7.9           2.5            5.2
# 418        10.2         9.9           8.7            7.5
# 419        13.0         8.5           8.8            7.6
# 420        10.0         6.3           2.0            8.4
#
# [421 rows x 9 columns]

# %%
df_final.columns
# Out:
# Index(['AGS', 'Ort', '1_Stimmen AfD', '1_Stimmen CDU', '1_Stimmen FDP',
#        '1_Stimmen GRÜNE', '1_Stimmen LINKE', '1_Stimmen SPD',
#        '1_Stimmen Ungültige Stimmen', '1_Stimmen andere Parteien',
#        '1_Stimmen gültige Stimmen', '1_Anteil AfD', '1_Anteil CDU',
#        '1_Anteil FDP', '1_Anteil GRÜNE', '1_Anteil LINKE', '1_Anteil SPD',
#        '1_Anteil Ungültige Stimmen', '1_Anteil andere Parteien',
#        '1_Anteil gültige Stimmen', '2_Stimmen AfD', '2_Stimmen CDU',
#        '2_Stimmen FDP', '2_Stimmen GRÜNE', '2_Stimmen LINKE', '2_Stimmen SPD',
#        '2_Stimmen Ungültige Stimmen', '2_Stimmen andere Parteien',
#        '2_Stimmen gültige Stimmen', '2_Anteil AfD', '2_Anteil CDU',
#        '2_Anteil FDP', '2_Anteil GRÜNE', '2_Anteil LINKE', '2_Anteil SPD',
#        '2_Anteil Ungültige Stimmen', '2_Anteil andere Parteien',
#        '2_Anteil gültige Stimmen', 'WKNr', 'Stimmen Wahlberechtigte',
#        'Stimmen Wähler', 'Anteil Wahlberechtigte', 'Anteil Wähler',
#        '2017_AfD_%', '2017_CDU_%', '2017_LINKE_%', '2017_SPD_%', '2017_FDP_%',
#        '2017_GRÜNE_%', '2017_andere_%'],
#       dtype='object')

# %% [markdown]
# ## Gewinner bestimmen (wichtig für Einfärbung der Karte)

# %%
df_final["2_Gewinner"] = df_final[['2_Stimmen AfD', '2_Stimmen CDU',
       '2_Stimmen FDP', '2_Stimmen GRÜNE', '2_Stimmen LINKE', '2_Stimmen SPD']].idxmax(axis=1)
df_final["2_Gewinner"] = df_final["2_Gewinner"].str.split(" ")
df_final["2_Gewinner"] = df_final["2_Gewinner"].map(lambda x: x[1])

# %%
# TODO: stimmen1 gewinner!!!

# %%
df_final["2_Gewinner"]
# Out:
# 0      AfD
# 1      SPD
# 2      AfD
# 3      AfD
# 4      SPD
#       ...
# 414    SPD
# 415    AfD
# 416    SPD
# 417    AfD
# 418    AfD
# Name: 2_Gewinner, Length: 419, dtype: object

# %%
df_final.to_csv("wahlergebnisse_testdaten.csv", index=False)

# %%
df_final[df_final.Ort.str.contains("Schlema")]
# Out:
# Empty DataFrame
# Columns: [AGS, Ort, 1_Stimmen AfD, 1_Stimmen CDU, 1_Stimmen FDP, 1_Stimmen GRÜNE, 1_Stimmen LINKE, 1_Stimmen SPD, 1_Stimmen Ungültige Stimmen, 1_Stimmen andere Parteien, 1_Stimmen gültige Stimmen, 1_Anteil AfD, 1_Anteil CDU, 1_Anteil FDP, 1_Anteil GRÜNE, 1_Anteil LINKE, 1_Anteil SPD, 1_Anteil Ungültige Stimmen, 1_Anteil andere Parteien, 1_Anteil gültige Stimmen, 2_Stimmen AfD, 2_Stimmen CDU, 2_Stimmen FDP, 2_Stimmen GRÜNE, 2_Stimmen LINKE, 2_Stimmen SPD, 2_Stimmen Ungültige Stimmen, 2_Stimmen andere Parteien, 2_Stimmen gültige Stimmen, 2_Anteil AfD, 2_Anteil CDU, 2_Anteil FDP, 2_Anteil GRÜNE, 2_Anteil LINKE, 2_Anteil SPD, 2_Anteil Ungültige Stimmen, 2_Anteil andere Parteien, 2_Anteil gültige Stimmen, WKNr, Stimmen Wahlberechtigte, Stimmen Wähler, Anteil Wahlberechtigte, Anteil Wähler, 2017_AfD_%, 2017_CDU_%, 2017_LINKE_%, 2017_SPD_%, 2017_FDP_%, 2017_GRÜNE_%, 2017_andere_%, 2_Gewinner]
# Index: []
#
# [0 rows x 51 columns]

# %% [markdown]
# Grundsätzlich haben wir **sechs freie Parteien-Slots** und andere Parteien. Die sechs gesetzten Parteien möchten wir jetzt nach Stärke verteilen.
#
# **Zunächst nutzen wir dabei nur die Zweitstimmen**, bei Erststimmen müssen wir nochmal schauen
#
#
# Dafür nutze ich die Daten **vor** dem long to wide. Die Long-Daten finden sich in diesen Dataframes:
#
# df_es_flat
#
# df_zs_flat

# %% [markdown]
# ## Zweitstimmen nach Stärke

# %%
def sort_parties(df): 
    
    cols = ["AGS", "Ort", "Gewinner",\
            "Partei_1_Stimmen", "Partei_1_Anteil", "Partei_1_Name",\
            "Partei_2_Stimmen", "Partei_2_Anteil", "Partei_2_Name",\
            "Partei_3_Stimmen", "Partei_3_Anteil", "Partei_3_Name",\
            "Partei_4_Stimmen", "Partei_4_Anteil", "Partei_4_Name",\
            "Partei_5_Stimmen", "Partei_5_Anteil", "Partei_5_Name",\
            "Partei_6_Stimmen", "Partei_6_Anteil", "Partei_6_Name",\
            "Partei_andere_Stimmen", "Partei_andere_Anteil", "Partei_andere_Name", \
           "ungültige Stimmen", "gültige Stimmen"]
            
           
      
    new_df = pd.DataFrame(columns=cols)
    
    # jeder Ort wird durchlaufen
    for ags in df["AGS"].unique():
        dict_var = {}
        df_ = df[df["AGS"]==ags]
        ort = df_.iloc[0].Ort
        
        
        # "andere Parteien" erfassen
        andere = df_[df_["Partei"]=="andere Parteien"]
        if andere.shape[0]>0:
            andere_stimmen = andere.Stimmen.item()
            andere_anteil = andere.Anteil.item()
            andere_name = "andere Parteien"
        else:
            andere_stimmen = 0
            andere_anteil = 0
            andere_name = "andere Parteien"
            
        
        # ungültige Stimmen erfassen
        ungültig = df_[df_["Partei"]=="Ungültige Stimmen"]["Stimmen"].item()
        gültig = df_[df_["Partei"]=="gültige Stimmen"]["Stimmen"].item()
        
        
        # andere Parteien herausfiltern (da sie sonst ev. einen Platz in der Parteienrangfolge einnehmen)
        df_ = df_[~df_.Partei.isin(["Ungültige Stimmen", "gültige Stimmen", "andere Parteien"])]
            
        # Parteien nach Stimmen sortieren, höchste zuerst
        df_sort = df_.sort_values(by="Stimmen", ascending=False)
        # Gewinner als Klarnamen herausfiltern
        gewinner = df_sort.iloc[0]["Partei"]
        
        # Durchlauf durch die AGS, für jede Gemeinde sechs Parteien in Rangfolge setzen
        for i in range(len(df_sort.index)):
            j = i+1
            
            j = i+1
            var_stimmen = f"partei_{j}_Stimmen"
            var_anteil = f"partei_{j}_Anteil"
            var_name = f"partei_{j}_Name"
            val_stimmen = df_sort.iloc[i]["Stimmen"]
            val_anteil = df_sort.iloc[i]["Anteil"]
            val_name = df_sort.iloc[i]["Partei"]
            
            dict_var[var_stimmen] = val_stimmen
            dict_var[var_anteil] = val_anteil
            dict_var[var_name] = val_name
            
        
        new_ser = pd.Series([ags, ort, gewinner, \
                             dict_var['partei_1_Stimmen'],dict_var['partei_1_Anteil'], dict_var['partei_1_Name'],\
                             dict_var['partei_2_Stimmen'],dict_var['partei_2_Anteil'], dict_var['partei_2_Name'],\
                             dict_var['partei_3_Stimmen'],dict_var['partei_3_Anteil'], dict_var['partei_3_Name'],\
                             dict_var['partei_4_Stimmen'],dict_var['partei_4_Anteil'], dict_var['partei_4_Name'],\
                             dict_var['partei_5_Stimmen'],dict_var['partei_5_Anteil'], dict_var['partei_5_Name'],\
                             dict_var['partei_6_Stimmen'],dict_var['partei_6_Anteil'], dict_var['partei_6_Name'],\
                             andere_stimmen, andere_anteil, andere_name, \
                             ungültig, gültig
                            ], index=cols)
        
        new_df = new_df.append(new_ser, ignore_index=True)
    
    # richtige Datentypen vergeben
    new_df[["Partei_andere_Stimmen", "ungültige Stimmen", "gültige Stimmen"]] = \
        new_df[["Partei_andere_Stimmen", "ungültige Stimmen", "gültige Stimmen"]].astype(int)
    
    new_df["Partei_andere_Anteil"] = round(new_df["Partei_andere_Stimmen"] / new_df["gültige Stimmen"] * 100,1)
    
    return new_df
            
            
        
        
        
    
    
df_zs_rank = sort_parties(df_zs_flat)

# %% [markdown]
# ## Erststimme nach Stärke

# %%
df_es_rank = sort_parties(df_es_flat)

# %%
# ACHTUNG, nur für Demozwecke
# df_es_rank["Gewinner"] = "Name, Vorname (" + df_es_rank['Gewinner'] + ")"
# df_es_rank["Partei_1_Name"] = "Name, Vorname (" + df_es_rank['Partei_1_Name'] + ")"
# df_es_rank["Partei_2_Name"] = "Name, Vorname (" + df_es_rank['Partei_2_Name'] + ")"
# df_es_rank["Partei_3_Name"] = "Name, Vorname (" + df_es_rank['Partei_3_Name'] + ")"
# df_es_rank["Partei_4_Name"] = "Name, Vorname (" + df_es_rank['Partei_4_Name'] + ")"
# df_es_rank["Partei_5_Name"] = "Name, Vorname (" + df_es_rank['Partei_5_Name'] + ")"
# df_es_rank["Partei_6_Name"] = "Name, Vorname (" + df_es_rank['Partei_6_Name'] + ")"

# %% [markdown]
# ## Partei nach Stärke mit WK-Daten mergen

# %%
# Schritt 1 - präfix vergeben
#Präfix _1 für Erststimme, _2 für Zweitstimme hinzufügen
df_es_rank = df_es_rank.add_prefix("1_")
df_zs_rank = df_zs_rank.add_prefix("2_")
df_es_rank.rename(columns={"1_AGS":"AGS", "1_Ort":"Ort"}, inplace=True)
df_zs_rank.rename(columns={"2_AGS":"AGS", "2_Ort":"Ort"}, inplace=True)

# %%
# Schritt 2 - alle DAten zusammenfassen in eine Wide-Tabelle

df_merge = df_es_rank.merge(df_zs_rank, on=["AGS", "Ort"])
df_merge = df_merge.merge(df_daten_wide, on=["AGS", "Ort"])

# %%
df_merge.to_clipboard(decimal=",", index=False)
df_merge.to_csv("datawrapper_dummy.csv", index=False)

# %% [markdown]
# ## Wahlergebnisse 2017 einarbeiten

# %%
df_merge["2_Partei_1_2017_Anteil"] = 0
df_merge["2_Partei_2_2017_Anteil"] = 0
df_merge["2_Partei_3_2017_Anteil"] = 0
df_merge["2_Partei_4_2017_Anteil"] = 0
df_merge["2_Partei_5_2017_Anteil"] = 0
df_merge["2_Partei_6_2017_Anteil"] = 0
df_merge["2_Partei_andere_2017_Anteil"] = 0

# %%
# dfh = wahlergebnisse_2021.copy()

# def create_old_results(df, dfh): 
#     for i in df.index: 
        
#         dict_col_names = {"AfD":"2017_AfD_%", "CDU":"2017_CDU_%", "LINKE":"2017_LINKE_%", "SPD":"2017_SPD_%", \
#                          "FDP":"2017_FDP_%", "GRÜNE":"2017_GRÜNE_%", "andere Parteien":"2017_andere_%"} 
#         partei_1 = df.at[i, "2_Partei_1_Name"]
#         anteil_2017_1 = 
        
        
        
# create_old_results(df_merge)

# %%
dfh
# Out:
#           AGS                      Ort  2017_AfD_%  2017_CDU_%  2017_LINKE_%  \
# 0    14730010                  Arzberg        31.2        28.4          14.5
# 1    14730020         Bad Düben, Stadt        22.9        30.4          15.8
# 2    14730030                 Beilrode        28.4        30.7          13.8
# 3    14730045  Belgern-Schildau, Stadt        31.8        28.6          12.6
# 4    14730050                Cavertitz        32.4        31.0          13.0
# ..        ...                      ...         ...         ...           ...
# 419  14523420              Tirpersdorf        28.4        31.8          15.5
# 420  14523430            Treuen, Stadt        26.4        31.5          15.3
# 421  14523440           Triebel/Vogtl.        26.3        30.5          16.7
# 422  14523450               Weischlitz        24.7        33.8          14.2
# 423  14523460                    Werda        26.7        35.6          13.1
#
#      2017_SPD_%  2017_FDP_%  2017_GRÜNE_%  2017_andere_%
# 0          10.4         7.9           1.1            6.5
# 1          13.8         8.6           3.1            5.4
# 2          11.9         8.0           1.7            5.7
# 3          11.9         6.7           2.1            6.3
# 4           8.4         7.3           1.9            6.1
# ..          ...         ...           ...            ...
# 419        10.2         5.9           2.2            5.9
# 420        10.7         6.8           3.1            6.2
# 421        11.3         6.0           2.5            6.8
# 422        10.4         7.7           3.5            5.7
# 423         9.1         7.9           2.5            5.2
#
# [424 rows x 9 columns]

# %% [markdown]
# # ERSTSTIMME

# %%
# df_es
# Out:
#          AGS      Ort             Partei    Stimmart  Stimmen  Anteil
# 0   14730010  Arzberg  Ungültige Stimmen  Erststimme        7     0.9
# 2   14730010  Arzberg    gültige Stimmen  Erststimme      793    99.1
# 4   14730010  Arzberg                AfD  Erststimme      198    25.0
# 6   14730010  Arzberg                CDU  Erststimme       98    12.4
# 8   14730010  Arzberg              LINKE  Erststimme      100    12.6
# ..       ...      ...                ...         ...      ...     ...
# 30  14612000  Dresden                SPD  Erststimme    65702    24.9
# 34  14612000  Dresden  Ungültige Stimmen  Erststimme     2691     1.0
# 38  14612000  Dresden           dieBasis  Erststimme     3009     1.1
# 40  14612000  Dresden    gültige Stimmen  Erststimme   263882    99.0
# 42  14612000  Dresden                ÖDP  Erststimme     2272     0.9
#
# [5285 rows x 6 columns]

# %% [markdown]
# ## Kandidaten für jede Partei und Wahlkreis herausfiltern

# %%
df_k = pd.read_excel("./data/statistik-sachsen_bundestagswahl2021_direktbewerber.xlsx", header=1)

# %%
# nur Kandidaten der sechs größeren Parteien behalten
liste_parteien = ["AfD", "CDU", "DIE LINKE", "FDP", "GRÜNE", "SPD"]
df_kandidaten = df_k[df_k["Wahlvorschlag \nKurzbezeichnung"].isin(liste_parteien)] 
df_kandidaten["Full_Name"] = df_kandidaten['Name'] +" (" + df_kandidaten['Wahlvorschlag \nKurzbezeichnung']+")"

df_kandidaten.rename(columns={"Wahlkreis 151 Nordsachsen":"Wahlkreis", "Nummer":"Listennummer", \
                             "Wahlvorschlag \nKurzbezeichnung": "Partei", \
                              "Wahlvorschlag \nLangbezeichnung": "Partei_lang", \
                             "Name":"Name", "Full_Name": "Name_lang"}, inplace=True)
# richtige Formate vergeben
df_kandidaten["Wahlkreis"] = df_kandidaten["Wahlkreis"].astype(str)
df_kandidaten["Listennummer"] = df_kandidaten["Listennummer"].astype(str)
# Out:
# <ipython-input-267-9ed62e74cfbf>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_kandidaten["Full_Name"] = df_kandidaten['Name'] +" (" + df_kandidaten['Wahlvorschlag \nKurzbezeichnung']+")"
# c:\users\c_knoop\appdata\local\programs\python\python39\lib\site-packages\pandas\core\frame.py:5034: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
# <ipython-input-267-9ed62e74cfbf>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_kandidaten["Wahlkreis"] = df_kandidaten["Wahlkreis"].astype(str)
# <ipython-input-267-9ed62e74cfbf>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_kandidaten["Listennummer"] = df_kandidaten["Listennummer"].astype(str)

# %%
#alle Kandidaten behalten 
df_kandidaten_all = df_k.copy()
df_kandidaten_all["Full_Name"] = df_kandidaten_all['Name'] +" (" + df_kandidaten_all['Wahlvorschlag \nKurzbezeichnung']+")"

df_kandidaten_all.rename(columns={"Wahlkreis 151 Nordsachsen":"KreisId", "Nummer":"Listennummer", \
                             "Wahlvorschlag \nKurzbezeichnung": "Partei", \
                              "Wahlvorschlag \nLangbezeichnung": "Partei_lang", \
                             "Name":"Name", "Full_Name": "Name_lang", "Nummer":"ParteiId"}, inplace=True)

# %%
df_kandidaten_all
# Out:
#     Wahlkreis ParteiId     Partei  \
# 0         151        1        AfD
# 1         151        2        CDU
# 2         151        3  DIE LINKE
# 3         151        4        SPD
# 4         151        5        FDP
# ..        ...      ...        ...
# 200       166       12        ÖDP
# 201       166       15   dieBasis
# 202       166       17   III. Weg
# 203       166       36     Ischgl
# 204       166       38        LKR
#
#                                      Partei_lang  \
# 0                    Alternative für Deutschland
# 1    Christlich Demokratische Union Deutschlands
# 2                                      DIE LINKE
# 3        Sozialdemokratische Partei Deutschlands
# 4                     Freie Demokratische Partei
# ..                                           ...
# 200              Ökologisch-Demokratische Partei
# 201        Basisdemokratische Partei Deutschland
# 202                               DER DRITTE WEG
# 203                                       Ischgl
# 204                Liberal-Konservative Reformer
#
#                              Name                           Name_lang
# 0                  Bochmann, René                Bochmann, René (AfD)
# 1    Schenderlein, Dr. Christiane  Schenderlein, Dr. Christiane (CDU)
# 2                 Rubach, Philipp         Rubach, Philipp (DIE LINKE)
# 3                Kleinke, Rüdiger              Kleinke, Rüdiger (SPD)
# 4             Richter, Martin Max           Richter, Martin Max (FDP)
# ..                            ...                                 ...
# 200             Eichhorn, Dietmar             Eichhorn, Dietmar (ÖDP)
# 201                 Falcke, Mario            Falcke, Mario (dieBasis)
# 202                 Sieghart, Udo            Sieghart, Udo (III. Weg)
# 203        Gerisch, Claus Joachim     Gerisch, Claus Joachim (Ischgl)
# 204               Drechsel, David               Drechsel, David (LKR)
#
# [205 rows x 6 columns]

# %% [markdown]
# ## dict Übersetzung WK-Id WK-Name

# %%
wk_dict = {"151": "Nordsachsen", "152":"Leipzig I", "153": "Leipzig II", "154":"Leipziger Land", \
          "155": "Meißen", "156":"Bautzen I", "157":"Görlitz", "158":"SSOE", "159": "Dresden I", \
          "160": "Dresden II/Bautzen II", "161": "Mittelsachsen", "162":"Chemnitz", "163":"Chemnitzer Uml./Erzg. II", \
          "164": "Erzgebirgskreis I", "165":"Zwickau", "166":"Vogtlandkreis"}

# %% [markdown]
# ## Ergebnisse und Daten mergen

# %%
df_es.KreisId = df_es.KreisId.astype(str)
df_es.ParteiId = df_es.ParteiId.astype(str)

df_kandidaten_all.KreisId = df_kandidaten_all.KreisId.astype(str)
df_kandidaten_all.ParteiId = df_kandidaten_all.ParteiId.astype(str)
# Out:
# c:\users\c_knoop\appdata\local\programs\python\python39\lib\site-packages\pandas\core\generic.py:5516: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
df_all = pd.merge(df_es, df_kandidaten_all[["KreisId", "ParteiId", "Name_lang", "Name"]], \
                     on=["KreisId", "ParteiId"])

# %%
df_all
# Out:
#            AGS KreisId                      Ort    Partei ParteiId  \
# 0     14730010     151                  Arzberg       AfD        1
# 1     14730020     151         Bad Düben, Stadt       AfD        1
# 2     14730030     151                 Beilrode       AfD        1
# 3     14730045     151  Belgern-Schildau, Stadt       AfD        1
# 4     14730050     151                Cavertitz       AfD        1
# ...        ...     ...                      ...       ...      ...
# 3957  14523420     166              Tirpersdorf  III. Weg       17
# 3958  14523430     166            Treuen, Stadt  III. Weg       17
# 3959  14523440     166           Triebel/Vogtl.  III. Weg       17
# 3960  14523450     166               Weischlitz  III. Weg       17
# 3961  14523460     166                    Werda  III. Weg       17
#
#         Stimmart  Stimmen  Anteil                 Name_lang            Name
# 0     Erststimme      198    25.0      Bochmann, René (AfD)  Bochmann, René
# 1     Erststimme     1110    25.2      Bochmann, René (AfD)  Bochmann, René
# 2     Erststimme      568    25.3      Bochmann, René (AfD)  Bochmann, René
# 3     Erststimme      932    25.0      Bochmann, René (AfD)  Bochmann, René
# 4     Erststimme      283    24.5      Bochmann, René (AfD)  Bochmann, René
# ...          ...      ...     ...                       ...             ...
# 3957  Erststimme       69     6.6  Sieghart, Udo (III. Weg)   Sieghart, Udo
# 3958  Erststimme       28     0.6  Sieghart, Udo (III. Weg)   Sieghart, Udo
# 3959  Erststimme        0     0.0  Sieghart, Udo (III. Weg)   Sieghart, Udo
# 3960  Erststimme        0     0.0  Sieghart, Udo (III. Weg)   Sieghart, Udo
# 3961  Erststimme        0     0.0  Sieghart, Udo (III. Weg)   Sieghart, Udo
#
# [3962 rows x 10 columns]

# %% [markdown]
# ## Gewinner/Verlierer sortieren

# %%
dict_colors = {"AfD":"#009ee0", "CDU":"#32302e", "SPD":"#e3000f", "DIE LINKE":"#ab006d", \
               "GRÜNE":"#a0c864", "FDP":"#fccc00", "FREIE WÄHLER":"#f39401"}

# %%
def create_erststimme_datawrapper(df): 
    
    cols = ["AGS", "Ort", "KreisId", "KreisName", "Gewinner_Partei", "Gewinner_Name", "Gewinner_c", \
            "Partei_1", "Partei_1_k", "Partei_1_c", "Partei_1_a", \
           "Partei_2", "Partei_2_k", "Partei_2_c", "Partei_2_a",
           "Partei_3", "Partei_3_k", "Partei_3_c", "Partei_3_a",
           "fließtext_rest"]
    
    new_df = pd.DataFrame(columns=cols)
    
    
    
    
    
    all_ags = df.AGS.unique()
    for ags in all_ags:
        
        
        
        df_ = df[df.AGS==ags]
        ort = df_["Ort"].unique()[0]
        kreis = df_["KreisId"].unique()[0]
        kreisname = wk_dict[kreis]
        no_parties = ["Ungültige Stimmen", "gültige Stimmen"]
        df_reduce = df_[~df_.Partei.isin(no_parties)]
        
        df_sort = df_reduce.sort_values(by="Anteil", ascending=False)
        
         # HELPER get color
        def get_color(partei): 
            try: 
                return dict_colors[partei]
            except: 
                return "#b5152b"
        
        # Gewinner
        gewinner_partei = df_sort.iloc[0].Partei
        gewinner_name = df_sort.iloc[0].Name
        gewinner_color = get_color(gewinner_partei)
        
       
        
        # ersten drei Kandidaten
        partei1 = df_sort.iloc[0].Partei
        partei1_k = df_sort.iloc[0].Name
        partei1_c = get_color(partei1)
        partei1_a = df_sort.iloc[0].Anteil
        
         # ersten drei Kandidaten
        partei2 = df_sort.iloc[1].Partei
        partei2_k = df_sort.iloc[1].Name
        partei2_c = get_color(partei2)
        partei2_a = df_sort.iloc[1].Anteil
        
         # ersten drei Kandidaten
        partei3 = df_sort.iloc[2].Partei
        partei3_k = df_sort.iloc[2].Name
        partei3_c = get_color(partei3)
        partei3_a = df_sort.iloc[2].Anteil
        
        long_string = ""
        
        for i in range(2, len(df_sort)):
        
            party_string = f" +++ {df_sort.iloc[i].Name_lang}, {df_sort.iloc[i].Anteil}%"
            long_string = long_string + party_string
    
       
       
        
        
        data_ser = [ags, ort, kreis, kreisname, gewinner_partei, gewinner_name, gewinner_color, \
                   partei1, partei1_k, partei1_c, partei1_a, \
                   partei2, partei2_k, partei2_c, partei2_a, \
                   partei3, partei3_k, partei3_c, partei3_a, \
                   long_string]
        
        new_ser = pd.Series(data_ser, index=cols)
        
        new_df = new_df.append(new_ser, ignore_index=True)
    
    return new_df
    
df_es_dw = create_erststimme_datawrapper(df_all)

# %%
df_es_dw
# Out:
#           AGS                      Ort KreisId      KreisName Gewinner_Partei  \
# 0    14730010                  Arzberg     151    Nordsachsen             AfD
# 1    14730020         Bad Düben, Stadt     151    Nordsachsen             AfD
# 2    14730030                 Beilrode     151    Nordsachsen             AfD
# 3    14730045  Belgern-Schildau, Stadt     151    Nordsachsen             SPD
# 4    14730050                Cavertitz     151    Nordsachsen             SPD
# ..        ...                      ...     ...            ...             ...
# 412  14523420              Tirpersdorf     166  Vogtlandkreis             AfD
# 413  14523430            Treuen, Stadt     166  Vogtlandkreis             AfD
# 414  14523440           Triebel/Vogtl.     166  Vogtlandkreis             SPD
# 415  14523450               Weischlitz     166  Vogtlandkreis             AfD
# 416  14523460                    Werda     166  Vogtlandkreis             AfD
#
#         Gewinner_Name Gewinner_c Partei_1        Partei_1_k Partei_1_c  \
# 0      Bochmann, René    #009ee0      AfD    Bochmann, René    #009ee0
# 1      Bochmann, René    #009ee0      AfD    Bochmann, René    #009ee0
# 2      Bochmann, René    #009ee0      AfD    Bochmann, René    #009ee0
# 3    Kleinke, Rüdiger    #e3000f      SPD  Kleinke, Rüdiger    #e3000f
# 4    Kleinke, Rüdiger    #e3000f      SPD  Kleinke, Rüdiger    #e3000f
# ..                ...        ...      ...               ...        ...
# 412   Weiser, Mathias    #009ee0      AfD   Weiser, Mathias    #009ee0
# 413   Weiser, Mathias    #009ee0      AfD   Weiser, Mathias    #009ee0
# 414   Burmeister, Kay    #e3000f      SPD   Burmeister, Kay    #e3000f
# 415   Weiser, Mathias    #009ee0      AfD   Weiser, Mathias    #009ee0
# 416   Weiser, Mathias    #009ee0      AfD   Weiser, Mathias    #009ee0
#
#      Partei_1_a Partei_2        Partei_2_k Partei_2_c  Partei_2_a    Partei_3  \
# 0          25.0      SPD  Kleinke, Rüdiger    #e3000f        24.2  Die PARTEI
# 1          25.2      SPD  Kleinke, Rüdiger    #e3000f        25.0         CDU
# 2          25.3      SPD  Kleinke, Rüdiger    #e3000f        25.2         CDU
# 3          25.1      AfD    Bochmann, René    #009ee0        25.0  Die PARTEI
# 4          24.7      AfD    Bochmann, René    #009ee0        24.5  Die PARTEI
# ..          ...      ...               ...        ...         ...         ...
# 412        24.2      SPD   Burmeister, Kay    #e3000f        24.1         CDU
# 413        25.2      SPD   Burmeister, Kay    #e3000f        25.0         ÖDP
# 414        25.5      AfD   Weiser, Mathias    #009ee0        24.8         ÖDP
# 415        24.9      SPD   Burmeister, Kay    #e3000f        24.6       LINKE
# 416        25.3      SPD   Burmeister, Kay    #e3000f        24.8         ÖDP
#
#                        Partei_3_k Partei_3_c  Partei_3_a  \
# 0                Gutjahr, Karsten    #b5152b        16.8
# 1    Schenderlein, Dr. Christiane    #32302e        12.5
# 2    Schenderlein, Dr. Christiane    #32302e        12.7
# 3                Gutjahr, Karsten    #b5152b        14.2
# 4                Gutjahr, Karsten    #b5152b        15.1
# ..                            ...        ...         ...
# 412                Magwas, Yvonne    #32302e        12.7
# 413             Eichhorn, Dietmar    #b5152b        13.1
# 414             Eichhorn, Dietmar    #b5152b        13.2
# 415               Höfer, Johannes    #b5152b        12.6
# 416             Eichhorn, Dietmar    #b5152b        12.6
#
#                                         fließtext_rest
# 0     +++ Gutjahr, Karsten (Die PARTEI), 16.8% +++ ...
# 1     +++ Schenderlein, Dr. Christiane (CDU), 12.5%...
# 2     +++ Schenderlein, Dr. Christiane (CDU), 12.7%...
# 3     +++ Gutjahr, Karsten (Die PARTEI), 14.2% +++ ...
# 4     +++ Gutjahr, Karsten (Die PARTEI), 15.1% +++ ...
# ..                                                 ...
# 412   +++ Magwas, Yvonne (CDU), 12.7% +++ Höfer, Jo...
# 413   +++ Eichhorn, Dietmar (ÖDP), 13.1% +++ Magwas...
# 414   +++ Eichhorn, Dietmar (ÖDP), 13.2% +++ Magwas...
# 415   +++ Höfer, Johannes (DIE LINKE), 12.6% +++ Ma...
# 416   +++ Eichhorn, Dietmar (ÖDP), 12.6% +++ Magwas...
#
# [417 rows x 20 columns]

# %% [markdown]
# ## Grafik aktualisieren

# %%
chart_id = "pLIgz"
dw.add_data(chart_id, df_es_dw)

# Wahlbeteiligung und Quellen eintragen: 
source_name = "<b style='color: grey'>Landeswahlleiter</b>"
source_url = "https://wahlen.sachsen.de/bundestagswahl-2021.html"
byline = "Christoph Knoop | Die Mehrwertmacher GmbH"

unterzeile = f"<b>Ergebnis Erststimmen für Direktkandidaten</b><br>Graugefärbte Gemeinden noch ohne Ergebnis."
dw.update_description(chart_id,source_name=source_name, source_url=source_url,\
                      byline=byline, intro=unterzeile)

# Datenstand und Auszählungsstand eintragen
string_1 = "<b>Ergebnisse auf Gemeindeeben. Kandidaten, die in einer Gemeinde gewonnen haben, können trotzdem im gesamten Wahlkreis unterlegen sein.</b><br>"
string_date1 = f"Datenstand: {datenstand}."
#string_date1 = datenstand
#string_date2 = f" <b>{abfrage} ausgezählt.</b>"
string_final = string_1 + string_date1
props = {'annotate': {'notes': string_final}}
dw.update_metadata(chart_id, props)
dw.publish_chart(chart_id, display=False)
#endregion
print("Aktualisierung Zweitstimme Wahlkreise abgeschlossen.")
# Out:
# Chart updated!
# Chart's metadata updated!
# Aktualisierung Zweitstimme Wahlkreise abgeschlossen.

# %%
df_es_dw.to_csv("erststimme_map.csv", index=False, sep=",")

# %% [markdown]
# ## richtige Formate vergeben

# %%
cols = df_es_wide.loc[:,df_es_wide.columns.str.contains("1_Anteil")].columns
df_es_wide[cols] = df_es_wide[cols].apply(pd.to_numeric, downcast='float', errors='coerce')

# %%
df_es
# Out:
#          AGS      Ort             Partei    Stimmart  Stimmen  Anteil
# 0   14730010  Arzberg  Ungültige Stimmen  Erststimme        7     0.9
# 2   14730010  Arzberg    gültige Stimmen  Erststimme      793    99.1
# 4   14730010  Arzberg                AfD  Erststimme      198    25.0
# 6   14730010  Arzberg                CDU  Erststimme       98    12.4
# 8   14730010  Arzberg              LINKE  Erststimme      100    12.6
# ..       ...      ...                ...         ...      ...     ...
# 30  14612000  Dresden                SPD  Erststimme    65702    24.9
# 34  14612000  Dresden  Ungültige Stimmen  Erststimme     2691     1.0
# 38  14612000  Dresden           dieBasis  Erststimme     3009     1.1
# 40  14612000  Dresden    gültige Stimmen  Erststimme   263882    99.0
# 42  14612000  Dresden                ÖDP  Erststimme     2272     0.9
#
# [5285 rows x 6 columns]

# %% [markdown]
# ## Ergebnisse je nach Stimmstärke sortieren

# %%
df_es_wide_anteil = df_es_wide[['AGS', 'Ort','1_Anteil ASMUSfddB',
       '1_Anteil AfD', '1_Anteil AufrechterDemokrat', '1_Anteil Brähmig',
       '1_Anteil BüSo', '1_Anteil Bündnis C', '1_Anteil CDU',
       '1_Anteil Die Humanisten', '1_Anteil Die PARTEI', '1_Anteil FDP',
       '1_Anteil FREIE WÄHLER', '1_Anteil GRÜNE',
       '1_Anteil Gesundheitsforschung', '1_Anteil III. Weg', '1_Anteil LINKE',
       '1_Anteil MLPD', '1_Anteil PIRATEN', '1_Anteil SPD',
       '1_Anteil Ungültige Stimmen', '1_Anteil V-Partei³', '1_Anteil dieBasis',
       '1_Anteil gültige Stimmen', '1_Anteil ÖDP' ]]

# %%
    
    cols = ["AGS", "Ort", "Gewinner_Partei", "Gewinner_Name", "Gewinner_c", \
            "Partei_1", "Partei_1_k", "Partei_1_c", "Partei_1_a", \
           "Partei_2", "Partei_2_k", "Partei_2_c", "Partei_2_a",
           "Partei_3", "Partei_3_k", "Partei_3_c", "Partei_3_a",
           "fließtext_rest"]
    
    new_df = pd.DataFrame(columns=cols)
    
    all_ags = df.AGS.unique()
    
    for ags in all_ags: 
        df_ = df[df["AGS"]==ags]
        
        df_reduce = df_[df.columns[~df_.columns.isin(["AGS", "Ort", '1_Anteil Ungültige Stimmen', '1_Anteil gültige Stimmen'])]]
       
        gewinner_partei = df_reduce.idxmax(axis=1)
        print(gewinner_partei)
    
    
create_erststimme_datawrapper(df_es_wide_anteil)
# Out:
# 0    1_Anteil AfD
# dtype: object
# 1    1_Anteil SPD
# dtype: object
# 2    1_Anteil AfD
# dtype: object
# 3    1_Anteil AfD
# dtype: object
# 4    1_Anteil AfD
# dtype: object
# 5    1_Anteil SPD
# dtype: object
# 6    1_Anteil AfD
# dtype: object
# 7    1_Anteil SPD
# dtype: object
# 8    1_Anteil AfD
# dtype: object
# 9    1_Anteil SPD
# dtype: object
# 10    1_Anteil AfD
# dtype: object
# 11    1_Anteil AfD
# dtype: object
# 12    1_Anteil AfD
# dtype: object
# 13    1_Anteil SPD
# dtype: object
# 14    1_Anteil AfD
# dtype: object
# 15    1_Anteil AfD
# dtype: object
# 16    1_Anteil SPD
# dtype: object
# 17    1_Anteil SPD
# dtype: object
# 18    1_Anteil AfD
# dtype: object
# 19    1_Anteil AfD
# dtype: object
# 20    1_Anteil SPD
# dtype: object
# 21    1_Anteil AfD
# dtype: object
# 22    1_Anteil AfD
# dtype: object
# 23    1_Anteil AfD
# dtype: object
# 24    1_Anteil SPD
# dtype: object
# 25    1_Anteil SPD
# dtype: object
# 26    1_Anteil AfD
# dtype: object
# 27    1_Anteil SPD
# dtype: object
# 28    1_Anteil AfD
# dtype: object
# 29    1_Anteil AfD
# dtype: object
# 30    1_Anteil AfD
# dtype: object
# 31    1_Anteil SPD
# dtype: object
# 32    1_Anteil SPD
# dtype: object
# 33    1_Anteil SPD
# dtype: object
# 34    1_Anteil AfD
# dtype: object
# 35    1_Anteil AfD
# dtype: object
# 36    1_Anteil AfD
# dtype: object
# 37    1_Anteil SPD
# dtype: object
# 38    1_Anteil SPD
# dtype: object
# 39    1_Anteil SPD
# dtype: object
# 40    1_Anteil AfD
# dtype: object
# 41    1_Anteil SPD
# dtype: object
# 42    1_Anteil SPD
# dtype: object
# 43    1_Anteil AfD
# dtype: object
# 44    1_Anteil AfD
# dtype: object
# 45    1_Anteil SPD
# dtype: object
# 46    1_Anteil AfD
# dtype: object
# 47    1_Anteil AfD
# dtype: object
# 48    1_Anteil SPD
# dtype: object
# 49    1_Anteil AfD
# dtype: object
# 50    1_Anteil AfD
# dtype: object
# 51    1_Anteil AfD
# dtype: object
# 52    1_Anteil SPD
# dtype: object
# 53    1_Anteil SPD
# dtype: object
# 54    1_Anteil AfD
# dtype: object
# 55    1_Anteil SPD
# dtype: object
# 56    1_Anteil AfD
# dtype: object
# 57    1_Anteil AfD
# dtype: object
# 58    1_Anteil SPD
# dtype: object
# 59    1_Anteil SPD
# dtype: object
# 60    1_Anteil SPD
# dtype: object
# 61    1_Anteil SPD
# dtype: object
# 62    1_Anteil AfD
# dtype: object
# 63    1_Anteil AfD
# dtype: object
# 64    1_Anteil SPD
# dtype: object
# 65    1_Anteil SPD
# dtype: object
# 66    1_Anteil AfD
# dtype: object
# 67    1_Anteil AfD
# dtype: object
# 68    1_Anteil SPD
# dtype: object
# 69    1_Anteil SPD
# dtype: object
# 70    1_Anteil AfD
# dtype: object
# 71    1_Anteil SPD
# dtype: object
# 72    1_Anteil AfD
# dtype: object
# 73    1_Anteil SPD
# dtype: object
# 74    1_Anteil AfD
# dtype: object
# 75    1_Anteil SPD
# dtype: object
# 76    1_Anteil SPD
# dtype: object
# 77    1_Anteil SPD
# dtype: object
# 78    1_Anteil AfD
# dtype: object
# 79    1_Anteil SPD
# dtype: object
# 80    1_Anteil SPD
# dtype: object
# 81    1_Anteil SPD
# dtype: object
# 82    1_Anteil SPD
# dtype: object
# 83    1_Anteil SPD
# dtype: object
# 84    1_Anteil SPD
# dtype: object
# 85    1_Anteil SPD
# dtype: object
# 86    1_Anteil AfD
# dtype: object
# 87    1_Anteil AfD
# dtype: object
# 88    1_Anteil SPD
# dtype: object
# 89    1_Anteil SPD
# dtype: object
# 90    1_Anteil SPD
# dtype: object
# 91    1_Anteil AfD
# dtype: object
# 92    1_Anteil SPD
# dtype: object
# 93    1_Anteil AfD
# dtype: object
# 94    1_Anteil SPD
# dtype: object
# 95    1_Anteil AfD
# dtype: object
# 96    1_Anteil AfD
# dtype: object
# 97    1_Anteil SPD
# dtype: object
# 98    1_Anteil SPD
# dtype: object
# 99    1_Anteil SPD
# dtype: object
# 100    1_Anteil AfD
# dtype: object
# 101    1_Anteil AfD
# dtype: object
# 102    1_Anteil AfD
# dtype: object
# 103    1_Anteil SPD
# dtype: object
# 104    1_Anteil SPD
# dtype: object
# 105    1_Anteil SPD
# dtype: object
# 106    1_Anteil AfD
# dtype: object
# 107    1_Anteil SPD
# dtype: object
# 108    1_Anteil AfD
# dtype: object
# 109    1_Anteil SPD
# dtype: object
# 110    1_Anteil AfD
# dtype: object
# 111    1_Anteil SPD
# dtype: object
# 112    1_Anteil SPD
# dtype: object
# 113    1_Anteil SPD
# dtype: object
# 114    1_Anteil SPD
# dtype: object
# 115    1_Anteil SPD
# dtype: object
# 116    1_Anteil AfD
# dtype: object
# 117    1_Anteil AfD
# dtype: object
# 118    1_Anteil AfD
# dtype: object
# 119    1_Anteil SPD
# dtype: object
# 120    1_Anteil AfD
# dtype: object
# 121    1_Anteil SPD
# dtype: object
# 122    1_Anteil AfD
# dtype: object
# 123    1_Anteil AfD
# dtype: object
# 124    1_Anteil SPD
# dtype: object
# 125    1_Anteil SPD
# dtype: object
# 126    1_Anteil SPD
# dtype: object
# 127    1_Anteil AfD
# dtype: object
# 128    1_Anteil SPD
# dtype: object
# 129    1_Anteil SPD
# dtype: object
# 130    1_Anteil AfD
# dtype: object
# 131    1_Anteil SPD
# dtype: object
# 132    1_Anteil SPD
# dtype: object
# 133    1_Anteil SPD
# dtype: object
# 134    1_Anteil AfD
# dtype: object
# 135    1_Anteil AfD
# dtype: object
# 136    1_Anteil AfD
# dtype: object
# 137    1_Anteil AfD
# dtype: object
# 138    1_Anteil AfD
# dtype: object
# 139    1_Anteil SPD
# dtype: object
# 140    1_Anteil SPD
# dtype: object
# 141    1_Anteil SPD
# dtype: object
# 142    1_Anteil SPD
# dtype: object
# 143    1_Anteil SPD
# dtype: object
# 144    1_Anteil SPD
# dtype: object
# 145    1_Anteil AfD
# dtype: object
# 146    1_Anteil AfD
# dtype: object
# 147    1_Anteil SPD
# dtype: object
# 148    1_Anteil AfD
# dtype: object
# 149    1_Anteil AfD
# dtype: object
# 150    1_Anteil AfD
# dtype: object
# 151    1_Anteil AfD
# dtype: object
# 152    1_Anteil SPD
# dtype: object
# 153    1_Anteil SPD
# dtype: object
# 154    1_Anteil AfD
# dtype: object
# 155    1_Anteil SPD
# dtype: object
# 156    1_Anteil SPD
# dtype: object
# 157    1_Anteil SPD
# dtype: object
# 158    1_Anteil SPD
# dtype: object
# 159    1_Anteil SPD
# dtype: object
# 160    1_Anteil AfD
# dtype: object
# 161    1_Anteil SPD
# dtype: object
# 162    1_Anteil SPD
# dtype: object
# 163    1_Anteil SPD
# dtype: object
# 164    1_Anteil SPD
# dtype: object
# 165    1_Anteil AfD
# dtype: object
# 166    1_Anteil SPD
# dtype: object
# 167    1_Anteil SPD
# dtype: object
# 168    1_Anteil SPD
# dtype: object
# 169    1_Anteil SPD
# dtype: object
# 170    1_Anteil SPD
# dtype: object
# 171    1_Anteil AfD
# dtype: object
# 172    1_Anteil SPD
# dtype: object
# 173    1_Anteil SPD
# dtype: object
# 174    1_Anteil SPD
# dtype: object
# 175    1_Anteil SPD
# dtype: object
# 176    1_Anteil AfD
# dtype: object
# 177    1_Anteil SPD
# dtype: object
# 178    1_Anteil SPD
# dtype: object
# 179    1_Anteil SPD
# dtype: object
# 180    1_Anteil SPD
# dtype: object
# 181    1_Anteil SPD
# dtype: object
# 182    1_Anteil SPD
# dtype: object
# 183    1_Anteil AfD
# dtype: object
# 184    1_Anteil SPD
# dtype: object
# 185    1_Anteil AfD
# dtype: object
# 186    1_Anteil AfD
# dtype: object
# 187    1_Anteil AfD
# dtype: object
# 188    1_Anteil AfD
# dtype: object
# 189    1_Anteil AfD
# dtype: object
# 190    1_Anteil AfD
# dtype: object
# 191    1_Anteil SPD
# dtype: object
# 192    1_Anteil SPD
# dtype: object
# 193    1_Anteil AfD
# dtype: object
# 194    1_Anteil AfD
# dtype: object
# 195    1_Anteil AfD
# dtype: object
# 196    1_Anteil AfD
# dtype: object
# 197    1_Anteil SPD
# dtype: object
# 198    1_Anteil SPD
# dtype: object
# 199    1_Anteil AfD
# dtype: object
# 200    1_Anteil SPD
# dtype: object
# 201    1_Anteil AfD
# dtype: object
# 202    1_Anteil AfD
# dtype: object
# 203    1_Anteil SPD
# dtype: object
# 204    1_Anteil AfD
# dtype: object
# 205    1_Anteil AfD
# dtype: object
# 206    1_Anteil AfD
# dtype: object
# 207    1_Anteil SPD
# dtype: object
# 208    1_Anteil SPD
# dtype: object
# 209    1_Anteil AfD
# dtype: object
# 210    1_Anteil AfD
# dtype: object
# 211    1_Anteil SPD
# dtype: object
# 212    1_Anteil AfD
# dtype: object
# 213    1_Anteil SPD
# dtype: object
# 214    1_Anteil SPD
# dtype: object
# 215    1_Anteil AfD
# dtype: object
# 216    1_Anteil SPD
# dtype: object
# 217    1_Anteil SPD
# dtype: object
# 218    1_Anteil SPD
# dtype: object
# 219    1_Anteil AfD
# dtype: object
# 220    1_Anteil AfD
# dtype: object
# 221    1_Anteil AfD
# dtype: object
# 222    1_Anteil SPD
# dtype: object
# 223    1_Anteil SPD
# dtype: object
# 224    1_Anteil SPD
# dtype: object
# 225    1_Anteil AfD
# dtype: object
# 226    1_Anteil AfD
# dtype: object
# 227    1_Anteil SPD
# dtype: object
# 228    1_Anteil AfD
# dtype: object
# 229    1_Anteil AfD
# dtype: object
# 230    1_Anteil AfD
# dtype: object
# 231    1_Anteil SPD
# dtype: object
# 232    1_Anteil AfD
# dtype: object
# 233    1_Anteil SPD
# dtype: object
# 234    1_Anteil AfD
# dtype: object
# 235    1_Anteil AfD
# dtype: object
# 236    1_Anteil AfD
# dtype: object
# 237    1_Anteil AfD
# dtype: object
# 238    1_Anteil SPD
# dtype: object
# 239    1_Anteil SPD
# dtype: object
# 240    1_Anteil SPD
# dtype: object
# 241    1_Anteil AfD
# dtype: object
# 242    1_Anteil SPD
# dtype: object
# 243    1_Anteil AfD
# dtype: object
# 244    1_Anteil SPD
# dtype: object
# 245    1_Anteil AfD
# dtype: object
# 246    1_Anteil AfD
# dtype: object
# 247    1_Anteil SPD
# dtype: object
# 248    1_Anteil SPD
# dtype: object
# 249    1_Anteil SPD
# dtype: object
# 250    1_Anteil AfD
# dtype: object
# 251    1_Anteil SPD
# dtype: object
# 252    1_Anteil AfD
# dtype: object
# 253    1_Anteil AfD
# dtype: object
# 254    1_Anteil AfD
# dtype: object
# 255    1_Anteil SPD
# dtype: object
# 256    1_Anteil SPD
# dtype: object
# 257    1_Anteil AfD
# dtype: object
# 258    1_Anteil AfD
# dtype: object
# 259    1_Anteil AfD
# dtype: object
# 260    1_Anteil SPD
# dtype: object
# 261    1_Anteil AfD
# dtype: object
# 262    1_Anteil AfD
# dtype: object
# 263    1_Anteil AfD
# dtype: object
# 264    1_Anteil AfD
# dtype: object
# 265    1_Anteil AfD
# dtype: object
# 266    1_Anteil SPD
# dtype: object
# 267    1_Anteil AfD
# dtype: object
# 268    1_Anteil SPD
# dtype: object
# 269    1_Anteil AfD
# dtype: object
# 270    1_Anteil AfD
# dtype: object
# 271    1_Anteil AfD
# dtype: object
# 272    1_Anteil AfD
# dtype: object
# 273    1_Anteil AfD
# dtype: object
# 274    1_Anteil AfD
# dtype: object
# 275    1_Anteil SPD
# dtype: object
# 276    1_Anteil SPD
# dtype: object
# 277    1_Anteil AfD
# dtype: object
# 278    1_Anteil AfD
# dtype: object
# 279    1_Anteil SPD
# dtype: object
# 280    1_Anteil AfD
# dtype: object
# 281    1_Anteil SPD
# dtype: object
# 282    1_Anteil AfD
# dtype: object
# 283    1_Anteil AfD
# dtype: object
# 284    1_Anteil AfD
# dtype: object
# 285    1_Anteil AfD
# dtype: object
# 286    1_Anteil AfD
# dtype: object
# 287    1_Anteil SPD
# dtype: object
# 288    1_Anteil SPD
# dtype: object
# 289    1_Anteil SPD
# dtype: object
# 290    1_Anteil SPD
# dtype: object
# 291    1_Anteil AfD
# dtype: object
# 292    1_Anteil AfD
# dtype: object
# 293    1_Anteil AfD
# dtype: object
# 294    1_Anteil AfD
# dtype: object
# 295    1_Anteil SPD
# dtype: object
# 296    1_Anteil SPD
# dtype: object
# 297    1_Anteil SPD
# dtype: object
# 298    1_Anteil SPD
# dtype: object
# 299    1_Anteil SPD
# dtype: object
# 300    1_Anteil AfD
# dtype: object
# 301    1_Anteil AfD
# dtype: object
# 302    1_Anteil SPD
# dtype: object
# 303    1_Anteil SPD
# dtype: object
# 304    1_Anteil AfD
# dtype: object
# 305    1_Anteil AfD
# dtype: object
# 306    1_Anteil AfD
# dtype: object
# 307    1_Anteil SPD
# dtype: object
# 308    1_Anteil SPD
# dtype: object
# 309    1_Anteil AfD
# dtype: object
# 310    1_Anteil SPD
# dtype: object
# 311    1_Anteil SPD
# dtype: object
# 312    1_Anteil SPD
# dtype: object
# 313    1_Anteil ASMUSfddB
# dtype: object
# 314    1_Anteil AfD
# dtype: object
# 315    1_Anteil SPD
# dtype: object
# 316    1_Anteil AfD
# dtype: object
# 317    1_Anteil AfD
# dtype: object
# 318    1_Anteil AfD
# dtype: object
# 319    1_Anteil SPD
# dtype: object
# 320    1_Anteil SPD
# dtype: object
# 321    1_Anteil SPD
# dtype: object
# 322    1_Anteil AfD
# dtype: object
# 323    1_Anteil AfD
# dtype: object
# 324    1_Anteil AfD
# dtype: object
# 325    1_Anteil SPD
# dtype: object
# 326    1_Anteil AfD
# dtype: object
# 327    1_Anteil SPD
# dtype: object
# 328    1_Anteil AfD
# dtype: object
# 329    1_Anteil AfD
# dtype: object
# 330    1_Anteil SPD
# dtype: object
# 331    1_Anteil AfD
# dtype: object
# 332    1_Anteil AfD
# dtype: object
# 333    1_Anteil AfD
# dtype: object
# 334    1_Anteil SPD
# dtype: object
# 335    1_Anteil SPD
# dtype: object
# 336    1_Anteil AfD
# dtype: object
# 337    1_Anteil AfD
# dtype: object
# 338    1_Anteil AfD
# dtype: object
# 339    1_Anteil AfD
# dtype: object
# 340    1_Anteil AfD
# dtype: object
# 341    1_Anteil AfD
# dtype: object
# 342    1_Anteil AfD
# dtype: object
# 343    1_Anteil AfD
# dtype: object
# 344    1_Anteil AfD
# dtype: object
# 345    1_Anteil SPD
# dtype: object
# 346    1_Anteil SPD
# dtype: object
# 347    1_Anteil SPD
# dtype: object
# 348    1_Anteil AfD
# dtype: object
# 349    1_Anteil AfD
# dtype: object
# 350    1_Anteil SPD
# dtype: object
# 351    1_Anteil AfD
# dtype: object
# 352    1_Anteil SPD
# dtype: object
# 353    1_Anteil AfD
# dtype: object
# 354    1_Anteil SPD
# dtype: object
# 355    1_Anteil AfD
# dtype: object
# 356    1_Anteil SPD
# dtype: object
# 357    1_Anteil AfD
# dtype: object
# 358    1_Anteil CDU
# dtype: object
# 359    1_Anteil AfD
# dtype: object
# 360    1_Anteil AfD
# dtype: object
# 361    1_Anteil SPD
# dtype: object
# 362    1_Anteil SPD
# dtype: object
# 363    1_Anteil AfD
# dtype: object
# 364    1_Anteil AfD
# dtype: object
# 365    1_Anteil SPD
# dtype: object
# 366    1_Anteil SPD
# dtype: object
# 367    1_Anteil SPD
# dtype: object
# 368    1_Anteil AfD
# dtype: object
# 369    1_Anteil AfD
# dtype: object
# 370    1_Anteil AfD
# dtype: object
# 371    1_Anteil AfD
# dtype: object
# 372    1_Anteil LINKE
# dtype: object
# 373    1_Anteil AfD
# dtype: object
# 374    1_Anteil CDU
# dtype: object
# 375    1_Anteil AfD
# dtype: object
# 376    1_Anteil SPD
# dtype: object
# 377    1_Anteil AfD
# dtype: object
# 378    1_Anteil SPD
# dtype: object
# 379    1_Anteil AfD
# dtype: object
# 380    1_Anteil SPD
# dtype: object
# 381    1_Anteil SPD
# dtype: object
# 382    1_Anteil SPD
# dtype: object
# 383    1_Anteil AfD
# dtype: object
# 384    1_Anteil AfD
# dtype: object
# 385    1_Anteil AfD
# dtype: object
# 386    1_Anteil AfD
# dtype: object
# 387    1_Anteil AfD
# dtype: object
# 388    1_Anteil AfD
# dtype: object
# 389    1_Anteil AfD
# dtype: object
# 390    1_Anteil AfD
# dtype: object
# 391    1_Anteil AfD
# dtype: object
# 392    1_Anteil SPD
# dtype: object
# 393    1_Anteil SPD
# dtype: object
# 394    1_Anteil SPD
# dtype: object
# 395    1_Anteil AfD
# dtype: object
# 396    1_Anteil SPD
# dtype: object
# 397    1_Anteil AfD
# dtype: object
# 398    1_Anteil SPD
# dtype: object
# 399    1_Anteil SPD
# dtype: object
# 400    1_Anteil AfD
# dtype: object
# 401    1_Anteil AfD
# dtype: object
# 402    1_Anteil SPD
# dtype: object
# 403    1_Anteil SPD
# dtype: object
# 404    1_Anteil SPD
# dtype: object
# 405    1_Anteil SPD
# dtype: object
# 406    1_Anteil AfD
# dtype: object
# 407    1_Anteil SPD
# dtype: object
# 408    1_Anteil AfD
# dtype: object
# 409    1_Anteil AfD
# dtype: object
# 410    1_Anteil SPD
# dtype: object
# 411    1_Anteil SPD
# dtype: object
# 412    1_Anteil SPD
# dtype: object
# 413    1_Anteil AfD
# dtype: object
# 414    1_Anteil AfD
# dtype: object
# 415    1_Anteil AfD
# dtype: object
# 416    1_Anteil AfD
# dtype: object
# 417    1_Anteil AfD
# dtype: object
# 418    1_Anteil AfD
# dtype: object

# %%
df[df.columns[~df.columns.isin(['C','D'])]]
# Out:
# Index(['AGS', 'Ort', '1_Anteil ASMUSfddB', '1_Anteil AfD',
#        '1_Anteil AufrechterDemokrat', '1_Anteil Brähmig', '1_Anteil BüSo',
#        '1_Anteil Bündnis C', '1_Anteil CDU', '1_Anteil Die Humanisten',
#        '1_Anteil Die PARTEI', '1_Anteil FDP', '1_Anteil FREIE WÄHLER',
#        '1_Anteil GRÜNE', '1_Anteil Gesundheitsforschung', '1_Anteil III. Weg',
#        '1_Anteil LINKE', '1_Anteil MLPD', '1_Anteil PIRATEN', '1_Anteil SPD',
#        '1_Anteil Ungültige Stimmen', '1_Anteil V-Partei³', '1_Anteil dieBasis',
#        '1_Anteil gültige Stimmen', '1_Anteil ÖDP'],
#       dtype='object')

# %%
df_es.Partei.unique()
# Out:
# array(['Ungültige Stimmen', 'gültige Stimmen', 'AfD', 'CDU', 'LINKE',
#        'SPD', 'FDP', 'GRÜNE', 'Die PARTEI', 'FREIE WÄHLER', 'ÖDP',
#        'dieBasis', 'ASMUSfddB', 'AufrechterDemokrat', 'PIRATEN', 'MLPD',
#        'Gesundheitsforschung', 'Brähmig', 'V-Partei³', 'Bündnis C',
#        'III. Weg', 'BüSo', 'Die Humanisten'], dtype=object)

# %%
df_kandidaten
# Out:
#     Wahlkreis Listennummer     Partei  \
# 0         151            1        AfD
# 1         151            2        CDU
# 2         151            3  DIE LINKE
# 3         151            4        SPD
# 4         151            5        FDP
# ..        ...          ...        ...
# 195       166            2        CDU
# 196       166            3  DIE LINKE
# 197       166            4        SPD
# 198       166            5        FDP
# 199       166            6      GRÜNE
#
#                                      Partei_lang  \
# 0                    Alternative für Deutschland
# 1    Christlich Demokratische Union Deutschlands
# 2                                      DIE LINKE
# 3        Sozialdemokratische Partei Deutschlands
# 4                     Freie Demokratische Partei
# ..                                           ...
# 195  Christlich Demokratische Union Deutschlands
# 196                                    DIE LINKE
# 197      Sozialdemokratische Partei Deutschlands
# 198                   Freie Demokratische Partei
# 199                        BÜNDNIS 90/DIE GRÜNEN
#
#                              Name                           Name_lang
# 0                  Bochmann, René                Bochmann, René (AfD)
# 1    Schenderlein, Dr. Christiane  Schenderlein, Dr. Christiane (CDU)
# 2                 Rubach, Philipp         Rubach, Philipp (DIE LINKE)
# 3                Kleinke, Rüdiger              Kleinke, Rüdiger (SPD)
# 4             Richter, Martin Max           Richter, Martin Max (FDP)
# ..                            ...                                 ...
# 195                Magwas, Yvonne                Magwas, Yvonne (CDU)
# 196               Höfer, Johannes         Höfer, Johannes (DIE LINKE)
# 197               Burmeister, Kay               Burmeister, Kay (SPD)
# 198                 Ludwig, André                 Ludwig, André (FDP)
# 199                Horlbeck, Olaf              Horlbeck, Olaf (GRÜNE)
#
# [96 rows x 6 columns]

# %%
def find_candidates(df_results, df_candidates):
    all_ags = df_results.AGS.unique()
    
    # Helper um mit Partie-Namen die Listennummer herauszufinden
    def return_party_nr(p_name): 
        for nr, name in parteien_dict.items():
            if p_name == name:
                return nr
        
    
    for ags in all_ags: 
        df_ = df_results[df_results["AGS"]==ags]
        winner = df_["1_Partei_1_Name"].item()
        number_winner = return_party_nr(winner)
        wknr = df_["WKNr"].item()
        name_winner = ""
        try:
            name_winner = df_kandidaten[(df_kandidaten["Wahlkreis"]==wknr) & \
                                    (df_kandidaten["Listennummer"]==number_winner)]["Name_lang"].item()
        except: 
            print(wknr)
            print(ags)
            print(number_winner)
            print(winner)
        #percent_share_winner = 
    
        df_results.loc[df_results["AGS"]==ags, "1_Gewinner"] = name_winner + " (" ")"
    

    
    
    return df_results




        
df_fin = find_candidates(df_merge, df_kandidaten)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-166-8434e41e4a46> in <module>
#      36
#      37
# ---> 38 df_fin = find_candidates(df_merge, df_kandidaten)
#
# NameError: name 'df_merge' is not defined

# %% [markdown]
# ## Leipzig und Dresden haben je zwei Wahlkreise... Winner verändern

# %% [markdown]
# Hier muss ich auf Werte zurückgreifen, die

# %%
wknr = "164"
number_winner = "2"
df_kandidaten[df_kandidaten["Listennummer"]==1]
# Out:
#     Wahlkreis Listennummer Partei                  Partei_lang  \
# 0         151            1    AfD  Alternative für Deutschland
# 13        152            1    AfD  Alternative für Deutschland
# 30        153            1    AfD  Alternative für Deutschland
# 45        154            1    AfD  Alternative für Deutschland
# 57        155            1    AfD  Alternative für Deutschland
# 69        156            1    AfD  Alternative für Deutschland
# 80        157            1    AfD  Alternative für Deutschland
# 91        158            1    AfD  Alternative für Deutschland
# 103       159            1    AfD  Alternative für Deutschland
# 119       160            1    AfD  Alternative für Deutschland
# 136       161            1    AfD  Alternative für Deutschland
# 145       162            1    AfD  Alternative für Deutschland
# 159       163            1    AfD  Alternative für Deutschland
# 170       164            1    AfD  Alternative für Deutschland
# 183       165            1    AfD  Alternative für Deutschland
# 194       166            1    AfD  Alternative für Deutschland
#
#                    Name                 Name_lang
# 0        Bochmann, René      Bochmann, René (AfD)
# 13   Neumann, Christoph  Neumann, Christoph (AfD)
# 30     Droese, Siegbert    Droese, Siegbert (AfD)
# 45        Naujok, Edgar       Naujok, Edgar (AfD)
# 57        Lenk, Barbara       Lenk, Barbara (AfD)
# 69       Hilse, Karsten      Hilse, Karsten (AfD)
# 80      Chrupalla, Tino     Chrupalla, Tino (AfD)
# 91      Janich, Steffen     Janich, Steffen (AfD)
# 103         Maier, Jens         Maier, Jens (AfD)
# 119     Harlaß, Andreas     Harlaß, Andreas (AfD)
# 136   Bachmann, Carolin   Bachmann, Carolin (AfD)
# 145  Klonovsky, Michael  Klonovsky, Michael (AfD)
# 159       Moncsek, Mike       Moncsek, Mike (AfD)
# 170       Dietz, Thomas       Dietz, Thomas (AfD)
# 183  Moosdorf, Matthias  Moosdorf, Matthias (AfD)
# 194     Weiser, Mathias     Weiser, Mathias (AfD)
