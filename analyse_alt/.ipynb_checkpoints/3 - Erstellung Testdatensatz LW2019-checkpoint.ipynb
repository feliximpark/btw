# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Creating Dataframe with fake data
# Dafür nehmen wir die Ergebnisse der letzten Landtagswahl und lassen das ganze zufällig schwanken.
# Das ist zwar teilweise verfälschend, weil wir dort andere Gebietszuschnitte hatten...
# ... aber das müssen wir jetzt mal so hinnehmen.

# %%
#testdaten_wahl = pd.read_csv("./Rohdaten/Testdaten_aus_LTW_2014.csv", encoding="utf-8", sep=";")
testdaten_wahl = pd.read_csv("./Daten_clean/ergebnisse_lt2019.csv", encoding="utf-8", sep=";")

# %%
testdaten_wahl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 434 entries, 0 to 433
# Data columns (total 47 columns):
# Unnamed: 0                434 non-null int64
# WK-Nr                     434 non-null int64
# AGS                       434 non-null int64
# Wahlberechtigte           434 non-null int64
# Wähler                    434 non-null int64
# ungültige_1               434 non-null int64
# ungültige_2               434 non-null int64
# gültige_1                 434 non-null int64
# gültige_2                 434 non-null int64
# CDU_1                     434 non-null int64
# LINKE_1                   434 non-null int64
# SPD_1                     434 non-null int64
# AfD_1                     434 non-null int64
# GRÜNE_1                   434 non-null int64
# NPD_1                     434 non-null int64
# FDP_1                     434 non-null int64
# FREIE WÄHLER_1            434 non-null int64
# Tierschutzpartei_1        434 non-null int64
# PIRATEN_1                 434 non-null int64
# Die PARTEI_1              434 non-null int64
# BüSo_1                    434 non-null int64
# ADPM_1                    434 non-null int64
# Blaue #TeamPetry_1        434 non-null int64
# KPD_1                     434 non-null int64
# ÖDP_1                     434 non-null int64
# Die Humanisten_1          434 non-null int64
# PDV_1                     434 non-null int64
# Gesundheitsforschung_1    434 non-null int64
# CDU_2                     434 non-null int64
# LINKE_2                   434 non-null int64
# SPD_2                     434 non-null int64
# AfD_2                     434 non-null int64
# GRÜNE_2                   434 non-null int64
# NPD_2                     434 non-null int64
# FDP_2                     434 non-null int64
# FREIE WÄHLER_2            434 non-null int64
# Tierschutzpartei_2        434 non-null int64
# PIRATEN_2                 434 non-null int64
# Die PARTEI_2              434 non-null int64
# BüSo_2                    434 non-null int64
# ADPM_2                    434 non-null int64
# Blaue #TeamPetry_2        434 non-null int64
# KPD_2                     434 non-null int64
# ÖDP_2                     434 non-null int64
# Die Humanisten_2          434 non-null int64
# PDV_2                     434 non-null int64
# Gesundheitsforschung_2    434 non-null int64
# dtypes: int64(47)
# memory usage: 159.4 KB

# %% [markdown]
# ### Merge mit den historischen Wahldaten

# %%
hist_df = pd.read_csv("./Daten_clean/historische_Wahldaten_bereinigt.csv", sep=";", encoding="utf-8")

# %%
test_wahl_aus_lw2014_und_historischen_daten = testdaten_wahl.merge(hist_df, on="AGS", how="left")
test_wahl_aus_lw2014_und_historischen_daten.drop(columns=["Unnamed: 0_x"], inplace=True)

# %%
test_wahl_aus_lw2014_und_historischen_daten.columns
# Out:
# Index(['WK-Nr', 'AGS', 'Wahlberechtigte', 'Wähler', 'ungültige_1',
#        'ungültige_2', 'gültige_1', 'gültige_2', 'CDU_1', 'LINKE_1',
#        ...
#        'GRÜNE_2_LW2014', 'NPD_2_LW2014', 'Tierschutzpartei_2_LW2014',
#        'PIRATEN_2_LW2014', 'BüSo_2_LW2014', 'DSU_2_LW2014', 'AfD_2_LW2014',
#        'pro Deutschland_2_LW2014', 'FREIE WÄHLER_2_LW2014',
#        'Die PARTEI_2_LW2014'],
#       dtype='object', length=104)

# %% [markdown]
# ### Richtige Datentypen vergeben - alle Zahlen in np.int64

# %%
# alle Ergebnisse in int konvertieren
cols=[i for i in test_wahl_aus_lw2014_und_historischen_daten.columns if i!="WK-Name_LW2014"]
for col in cols:
   
    test_wahl_aus_lw2014_und_historischen_daten[col]=pd.to_numeric(test_wahl_aus_lw2014_und_historischen_daten[col])
    test_wahl_aus_lw2014_und_historischen_daten[col]= test_wahl_aus_lw2014_und_historischen_daten[col].fillna(0).astype(int)

# %%
test_wahl_aus_lw2014_und_historischen_daten
# Out:
#      WK-Nr        AGS  Wahlberechtigte  Wähler  ungültige_1  ungültige_2  \
# 0        1   14523320            52165   32186          752          742
# 1        2   14523010             4112    2551           73           61
# 2        2   14523030             1549     971           14           19
# 3        2   14523040             3054    1979           56           48
# 4        2   14523050              822     553            7           13
# 5        2   14523060              953     429            7           17
# 6        2   14523080             1030     430           15           14
# 7        2   14523200             6340    4230          115          115
# 8        2   14523230             1109     534           14           11
# 9        2   14523300             8758    5514          136          131
# 10       2   14523310             4204    2529           51           53
# 11       2   14523365             3557    2244           49           57
# 12       2   14523370             2668    1544           26           28
# 13       2   14523410              854     523           10           12
# 14       2   14523420             1149     632           13           21
# 15       2   14523440             1036     566            6           12
# 16       2   14523450             4900    3014           68           84
# 17       2   14523460             1278     632           13           16
# 18       3   14523020            15573    9643          236          280
# 19       3   14523090             2126    1149           21           29
# 20       3   14523120             6784    4415          125           76
# 21       3   14523130             1453     928           21           34
# 22       3   14523160             7173    4171          115           93
# 23       3   14523245             2597    1464           27           34
# 24       3   14523270             1781    1146           31           34
# 25       3   14523290              842     545           12           18
# 26       3   14523430             6581    4062          104          108
# 27       4   14523100             3401    2195           42           54
# 28       4   14523150             1681     896           24           28
# 29       4   14523170             5949    3739           93           83
# ..     ...        ...              ...     ...          ...          ...
# 404     59   14626020              963     644           19           25
# 405     59   14626030             2806    1579           39           35
# 406     59   14626070              821     569           20            9
# 407     59   14626085            10145    6153          149          143
# 408     59   14626150             1091     637           19           11
# 409     59   14626180             4872    3080           59           75
# 410     59   14626245             6267    4296           92          102
# 411     59   14626270             1540     740           24           21
# 412     59   14626290            12233    7771          218          186
# 413     59   14626350             2790    1542           40           48
# 414     59   14626410             1984    1530           39           37
# 415     59   14626420             1888    1109           24           26
# 416     59   14626470             1255     828           26           23
# 417     59   14626500             1240     658           14           15
# 418     59   14626510              919     459           11           17
# 419     60   14626050             1782     924           31           25
# 420     60   14626140             4600    2780           75           66
# 421     60   14626170             1260     649            7           16
# 422     60   14626210             1332     664           19            9
# 423     60   14626280             2993    1761           55           33
# 424     60   14626310             3086    1954           63           56
# 425     60   14626390             4348    2294           65           75
# 426     60   14626400             3997    2384           74           66
# 427     60   14626430             1185     555           13           18
# 428     60   14626530             3120    1895           51           22
# 429     60   14626610            21048   13728          355          324
# 430    210  147130000           454193  287305         7230         7243
# 431    308  146120000           427120  263773         6565         6273
# 432     13  145243300            72960   46167         1112         1191
# 433     33  145110000           192593  121142         2964         2997
#
#      gültige_1  gültige_2  CDU_1  LINKE_1  ...  GRÜNE_2_LW2014  NPD_2_LW2014  \
# 0        31434      31444   7852     3934  ...            1195          1161
# 1         2478       2490    614      314  ...              33           119
# 2          957        952    229      119  ...              14            26
# 3         1923       1931    511      250  ...              57            50
# 4          546        540    146       69  ...               2            21
# 5          422        412    102       51  ...              16            25
# 6          415        416    106       48  ...              12            38
# 7         4115       4115    986      514  ...             104           121
# 8          520        523    135       62  ...               9            35
# 9         5378       5383   1367      688  ...             111           218
# 10        2478       2476    641      299  ...              91           129
# 11        2195       2187    553      272  ...              60           108
# 12        1518       1516    373      182  ...              51            84
# 13         513        511    116       62  ...              14            45
# 14         619        611    147       84  ...              14            14
# 15         560        554    129       71  ...               7            18
# 16        2946       2930    748      368  ...              97            86
# 17         619        616    163       82  ...              16            24
# 18        9407       9363   2344     1173  ...             223           301
# 19        1128       1120    276      136  ...              32            32
# 20        4290       4339   1103      519  ...              83           127
# 21         907        894    246      113  ...              17            18
# 22        4056       4078   1014      499  ...              73           140
# 23        1437       1430    379      178  ...              21            60
# 24        1115       1112    275      141  ...              25            74
# 25         533        527    142       69  ...               4             6
# 26        3958       3954    967      486  ...             102           161
# 27        2153       2141    522      263  ...              80            78
# 28         872        868    218      108  ...              29            20
# 29        3646       3656    888      455  ...              85           105
# ..         ...        ...    ...      ...  ...             ...           ...
# 404        625        619    159       74  ...              20            41
# 405       1540       1544    374      203  ...              59            60
# 406        549        560    129       71  ...              10            12
# 407       6004       6010   1502      779  ...             233           307
# 408        618        626    157       83  ...               8            27
# 409       3021       3005    764      396  ...             170           103
# 410       4204       4194   1032      515  ...             117           191
# 411        716        719    187       86  ...              16            61
# 412       7553       7585   1920      950  ...             151           400
# 413       1502       1494    390      193  ...              68           102
# 414       1491       1493    385      186  ...              25            88
# 415       1085       1083    276      132  ...              43            26
# 416        802        805    192       92  ...              19            51
# 417        644        643    160       77  ...               4            22
# 418        448        442    120       51  ...               8            25
# 419        893        899    224      117  ...              39            70
# 420       2705       2714    673      338  ...              86           149
# 421        642        633    155       75  ...              33            18
# 422        645        655    174       83  ...              30            35
# 423       1706       1728    434      213  ...              48            89
# 424       1891       1898    467      245  ...              69            95
# 425       2229       2219    571      271  ...             101           136
# 426       2310       2318    571      278  ...              96            94
# 427        542        537    143       63  ...              18            29
# 428       1844       1873    458      231  ...              67           116
# 429      13373      13404   3359     1695  ...             481           592
# 430     280075     280062  69745    34923  ...               0             0
# 431     257208     257500  64460    32283  ...               0             0
# 432      45055      44976  11213     5599  ...               0             0
# 433     118178     118145  29244    14725  ...               0             0
#
#      Tierschutzpartei_2_LW2014  PIRATEN_2_LW2014  BüSo_2_LW2014  DSU_2_LW2014  \
# 0                          253               186             23            49
# 1                           17                12              1             3
# 2                            3                 0              1             6
# 3                           22                 7              2             1
# 4                            7                 4              0             2
# 5                            7                 4              2             3
# 6                            7                 0              1             1
# 7                           31                15              4            11
# 8                            3                 4              0             1
# 9                           48                32              2            30
# 10                          18                12              0             8
# 11                           9                 8              1             3
# 12                          21                 9              0             6
# 13                          13                 3              1             2
# 14                           3                 2              0             2
# 15                           4                 5              0             1
# 16                          24                10              3            10
# 17                           2                 2              0             1
# 18                          75                42              6             8
# 19                           8                 3              0             4
# 20                          28                24              0             7
# 21                          10                 3              0             2
# 22                          25                21              0             5
# 23                          10                 6              0             2
# 24                          10                 3              1             7
# 25                           6                 2              0             0
# 26                          31                25              4            46
# 27                          32                22              1             6
# 28                           9                 2              0             2
# 29                          18                20              1             4
# ..                         ...               ...            ...           ...
# 404                          4                 3              0             1
# 405                         12                10              3             5
# 406                          3                 1              0             1
# 407                         43                35              4            14
# 408                          2                 3              1             0
# 409                         30                27              1             8
# 410                         38                26              4            12
# 411                          6                 2              2             3
# 412                         50                59             14             8
# 413                         23                13              8             4
# 414                          6                 1              0             0
# 415                          9                 5              3             1
# 416                          3                 3              1             0
# 417                          8                 4              0             1
# 418                          2                 3              0             0
# 419                         18                 5              1             0
# 420                         33                16              1             2
# 421                          9                 1              2             0
# 422                          7                 2              1             3
# 423                         10                 9              1             4
# 424                         17                15              3             3
# 425                         25                16              0             4
# 426                         42                24              4             6
# 427                          8                 1              2             0
# 428                         19                10              4             8
# 429                        117                99             21            16
# 430                          0                 0              0             0
# 431                          0                 0              0             0
# 432                          0                 0              0             0
# 433                          0                 0              0             0
#
#      AfD_2_LW2014  pro Deutschland_2_LW2014  FREIE WÄHLER_2_LW2014  \
# 0            2784                        25                    262
# 1             181                         3                     68
# 2              76                         0                     10
# 3             219                         6                     62
# 4              40                         0                      6
# 5              43                         0                      3
# 6              33                         0                     11
# 7             432                         4                     51
# 8              86                         1                      8
# 9             446                         3                     30
# 10            239                         2                     80
# 11            199                         1                     24
# 12            183                         1                     46
# 13             81                         0                      3
# 14             52                         0                      8
# 15             34                         2                     15
# 16            209                         2                     49
# 17             68                         3                     11
# 18            700                        11                     47
# 19             96                         4                      5
# 20            334                         4                     10
# 21             59                         0                      7
# 22            367                         9                     27
# 23             97                         1                     16
# 24            108                         2                      5
# 25             31                         1                      3
# 26            372                         4                     38
# 27            163                         3                     83
# 28             79                         2                      5
# 29            280                         3                     32
# ..            ...                       ...                    ...
# 404            94                         2                     13
# 405           213                         0                     24
# 406           141                         4                      7
# 407           716                        12                    120
# 408            99                         0                     14
# 409           319                         6                     48
# 410           525                         9                     83
# 411           140                         2                     19
# 412           861                         8                    210
# 413           298                         6                     71
# 414           156                         3                     52
# 415           108                         2                     16
# 416            71                         0                     29
# 417            71                         3                     11
# 418           100                         3                      6
# 419           124                         7                     42
# 420           364                         4                     49
# 421            79                         3                      9
# 422            87                         3                     32
# 423           199                         5                     30
# 424           217                         2                     68
# 425           360                         2                     91
# 426           344                        10                     73
# 427            59                         2                     11
# 428           267                         3                     42
# 429          1025                        32                    268
# 430             0                         0                      0
# 431             0                         0                      0
# 432             0                         0                      0
# 433             0                         0                      0
#
#      Die PARTEI_2_LW2014
# 0                    169
# 1                      4
# 2                      2
# 3                      7
# 4                      1
# 5                      1
# 6                      2
# 7                      9
# 8                      3
# 9                     16
# 10                    10
# 11                     4
# 12                     5
# 13                     4
# 14                     1
# 15                     1
# 16                     8
# 17                     1
# 18                    21
# 19                     2
# 20                    10
# 21                     2
# 22                     9
# 23                     2
# 24                     4
# 25                     2
# 26                    14
# 27                    12
# 28                     5
# 29                    14
# ..                   ...
# 404                    2
# 405                    6
# 406                    1
# 407                   21
# 408                    2
# 409                    8
# 410                    9
# 411                    2
# 412                   23
# 413                    4
# 414                    4
# 415                    9
# 416                    4
# 417                    2
# 418                    4
# 419                    4
# 420                   17
# 421                    3
# 422                    2
# 423                    5
# 424                    3
# 425                    5
# 426                    3
# 427                    1
# 428                    9
# 429                   57
# 430                    0
# 431                    0
# 432                    0
# 433                    0
#
# [434 rows x 104 columns]

# %%
# Ausspielen
test_wahl_aus_lw2014_und_historischen_daten.to_csv("./Daten_clean/test_wahl_aus_lw2014_und_historischen_daten.csv", 
                                                  encoding="utf-8", sep=";")

# %%
# alte Version, vielleicht mal aufbewahren


# cols = ['WK-Nr', 'AGS', 'Wahlberechtigte', 'Wähler', 'gültige_1',
#        'CDU_1', 'DIE LINKE_1', 'SPD_1', 'FDP_1', 'GRÜNE_1', 'NPD_1',
#        'PIRATEN_1', 'BüSo_1', 'DSU_1', 'AfD_1', 'FREIE WÄHLER_1',
#        'Die PARTEI_1', 'Freie Bürger Leipzig_1', 'Konrad Skatula_1',
#        'Schaar_1', 'WAGNER_1', 'WV MFU_1', 'gültige_2', 'CDU_2', 'DIE LINKE_2',
#        'SPD_2', 'FDP_2', 'GRÜNE_2', 'NPD_2', 'Tierschutzpartei_2', 'PIRATEN_2',
#        'BüSo_2', 'DSU_2', 'AfD_2', 'pro Deutschland_2', 'FREIE WÄHLER_2',
#        'Die PARTEI_2', 'Unnamed: 0_y', 'Wahlberechtigte_EW2019',
#        'Wähler_EW2019', 'gültige_EW2019', 'CDU_EW2019', 'DIE LINKE_EW2019',
#        'SPD_EW2019', 'AfD_EW2019', 'GRÜNE_EW2019', 'FDP_EW2019',
#        'FREIE WÄHLER_EW2019', 'Wahlberechtigte_BW2017', 'Wähler_BW2017',
#        'gültige_2_BW2017', 'CDU_2_BW2017', 'DIE LINKE_2_BW2017',
#        'SPD_2_BW2017', 'AfD_2_BW2017', 'GRÜNE_2_BW2017', 'FDP_2_BW2017',
#        'FREIE WÄHLER_2_BW2017', 'WK-Nr_LW2014', 
#        'Wahlberechtigte_LW2014', 'Wähler_LW2014', 'gültige_1_LW2014',
#        'CDU_1_LW2014', 'DIE LINKE_1_LW2014', 'SPD_1_LW2014', 'FDP_1_LW2014',
#        'GRÜNE_1_LW2014', 'NPD_1_LW2014', 'PIRATEN_1_LW2014', 'BüSo_1_LW2014',
#        'DSU_1_LW2014', 'AfD_1_LW2014', 'FREIE WÄHLER_1_LW2014',
#        'Die PARTEI_1_LW2014', 'Freie Bürger Leipzig_1_LW2014',
#        'Konrad Skatula_1_LW2014', 'Schaar_1_LW2014', 'WAGNER_1_LW2014',
#        'WV MFU_1_LW2014', 'gültige_2_LW2014', 'CDU_2_LW2014',
#        'DIE LINKE_2_LW2014', 'SPD_2_LW2014', 'FDP_2_LW2014', 'GRÜNE_2_LW2014',
#        'NPD_2_LW2014', 'Tierschutzpartei_2_LW2014', 'PIRATEN_2_LW2014',
#        'BüSo_2_LW2014', 'DSU_2_LW2014', 'AfD_2_LW2014',
#        'pro Deutschland_2_LW2014', 'FREIE WÄHLER_2_LW2014',
#        'Die PARTEI_2_LW2014']

# test_wahl_aus_lw2014_und_historischen_daten[cols] = test_wahl_aus_lw2014_und_historischen_daten[cols].fillna(0).astype(np.int64)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-18-7475f0260d9f> in <module>
#      26        'Die PARTEI_2_LW2014']
#      27
# ---> 28 test_wahl_aus_lw2014_und_historischen_daten[cols] = test_wahl_aus_lw2014_und_historischen_daten[cols].fillna(0).astype(np.int64)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2932                 key = list(key)
#    2933             indexer = self.loc._convert_to_indexer(key, axis=1,
# -> 2934                                                    raise_missing=True)
#    2935
#    2936         # take() does not accept boolean indexers
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _convert_to_indexer(self, obj, axis, is_setter, raise_missing)
#    1352                 kwargs = {'raise_missing': True if is_setter else
#    1353                           raise_missing}
# -> 1354                 return self._get_listlike_indexer(obj, axis, **kwargs)[1]
#    1355         else:
#    1356             try:
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1159         self._validate_read_indexer(keyarr, indexer,
#    1160                                     o._get_axis_number(axis),
# -> 1161                                     raise_missing=raise_missing)
#    1162         return keyarr, indexer
#    1163
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1250             if not(self.name == 'loc' and not raise_missing):
#    1251                 not_found = list(set(key) - set(ax))
# -> 1252                 raise KeyError("{} not in index".format(not_found))
#    1253
#    1254             # we skip the warning on Categorical/Interval
#
# KeyError: "['Schaar_1', 'DIE LINKE_1', 'pro Deutschland_2', 'WAGNER_1', 'DSU_1', 'Konrad Skatula_1', 'Freie Bürger Leipzig_1', 'WV MFU_1', 'DIE LINKE_2', 'DSU_2'] not in index"
