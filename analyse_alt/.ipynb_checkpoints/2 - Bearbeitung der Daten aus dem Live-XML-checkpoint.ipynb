# %%
import pandas as pd
import numpy as np
# XML-Lib laden
import xml.etree.ElementTree as ET

# %% [markdown]
# ## XML-Datei laden - Ergebnisse auf Gemeindeebene

# %%
root = ET.parse("./Rohdaten/testdaten_wahl.xml").getroot()

# %%
columns = ["WK-Nr", "AGS", "Wahlberechtigte", "Wähler", "ungültige_1", "ungültige_2", 
           "gültige_1","gültige_2", "CDU_1", "LINKE_1", "SPD_1", "AfD_1", 
          "GRÜNE_1", "NPD_1", "FDP_1", "FREIE WÄHLER_1", "Tierschutzpartei_1", "PIRATEN_1", "Die PARTEI_1",
           "BüSo_1", "ADPM_1", "Blaue #TeamPetry_1", "KPD_1", "ÖDP_1", "Die Humanisten_1", "PDV_1", 
           "Gesundheitsforschung_1", 
          "CDU_2", "LINKE_2", "SPD_2", "AfD_2", 
          "GRÜNE_2", "NPD_2", "FDP_2", "FREIE WÄHLER_2", "Tierschutzpartei_2", "PIRATEN_2", "Die PARTEI_2",
           "BüSo_2", "ADPM_2", "Blaue #TeamPetry_2", "KPD_2", "ÖDP_2", "Die Humanisten_2", "PDV_2", 
           "Gesundheitsforschung_2"]

# finales Dataframe
df_ergebnisse = pd.DataFrame(columns=columns)

for elem in root: 
    # jetzt müssen sämtliche Variablen deklariert werden, damit sie durch if-else-Klauseln gefüllt werden können
    kreis = elem.attrib.get('KreisNr')
    gemeinde = elem.attrib.get('GemNr')
    wahlberechtigte = ""
    wähler = ""
    ungültige_1 = ""
    ungültige_2 = ""
    gültige_1 = ""
    gültige_2 = ""
    CDU_1 = "" 
    LINKE_1 =""
    SPD_1= "" 
    AfD_1 = ""
    GRÜNE_1 = ""
    NPD_1 = ""
    FDP_1 = ""
    FREIE_1 = ""
    Tierschutzpartei_1 = ""
    PIRATEN_1 = ""
    PARTEI_1 = "" 
    BüSo_1 = ""
    ADPM_1 = ""
    Blaue_1 = ""
    KPD_1 = "" 
    ÖDP_1 = ""
    Humanisten_1 = ""
    PDV_1 = ""
    Gesundheitsforschung_1 = ""
    
    #Zweitstimmen
    CDU_2 = "" 
    LINKE_2 =""
    SPD_2= "" 
    AfD_2 = ""
    GRÜNE_2 = ""
    NPD_2 = ""
    FDP_2 = ""
    FREIE_2 = ""
    Tierschutzpartei_2 = ""
    PIRATEN_2 = ""
    PARTEI_2 = "" 
    BüSo_2 = ""
    ADPM_2 = ""
    Blaue_2 = ""
    KPD_2 = "" 
    ÖDP_2 = ""
    Humanisten_2 = ""
    PDV_2 = ""
    Gesundheitsforschung_2 = ""
    
    
    
    
    
    
    for sub in elem: 
        # Identifikation der jeweiligen Information
        position = sub.attrib.get('Position')
        
        
        for subsub in sub:
            
            
           
            if position == "WB":
                wahlberechtigte = subsub.attrib.get("Stimmen")
            elif position == "WAE":
                wähler = subsub.attrib.get("Stimmen")
            elif position == "UNG":
                stimmart = subsub.attrib.get("Stimmart")
                if stimmart == "DIREKT": 
                    ungültige_1 = subsub.attrib.get("Stimmen")
                if stimmart == "LISTE": 
                    ungültige_2 = subsub.attrib.get("Stimmen")
            elif position == "GUE":
                stimmart = subsub.attrib.get("Stimmart")
                if stimmart == "DIREKT": 
                    gültige_1 = subsub.attrib.get("Stimmen")
                if stimmart == "LISTE": 
                    gültige_2 = subsub.attrib.get("Stimmen")
            elif position == "1":
                stimmart = subsub.attrib.get("Stimmart")
                if stimmart == "DIREKT": 
                    CDU_1 = subsub.attrib.get("Stimmen")
                if stimmart == "LISTE": 
                    CDU_2 = subsub.attrib.get("Stimmen")
            elif position == "2":
                stimmart = subsub.attrib.get("Stimmart")
                if stimmart == "DIREKT": 
                    LINKE_1 = subsub.attrib.get("Stimmen")
                if stimmart == "LISTE": 
                    LINKE_2 = subsub.attrib.get("Stimmen")
            elif position == "3":
                stimmart = subsub.attrib.get("Stimmart")
                if stimmart == "DIREKT": 
                    SPD_1 = subsub.attrib.get("Stimmen")
                if stimmart == "LISTE": 
                    SPD_2 = subsub.attrib.get("Stimmen")
            elif position == "4":
                stimmart = subsub.attrib.get("Stimmart")
                if stimmart == "DIREKT": 
                    AfD_1 = subsub.attrib.get("Stimmen")
                if stimmart == "LISTE": 
                    AfD_2 = subsub.attrib.get("Stimmen")
            elif position == "5":
                stimmart = subsub.attrib.get("Stimmart")
                if stimmart == "DIREKT": 
                    GRÜNE_1 = subsub.attrib.get("Stimmen")
                if stimmart == "LISTE": 
                    GRÜNE_2 = subsub.attrib.get("Stimmen")
            elif position == "6":
                stimmart = subsub.attrib.get("Stimmart")
                if stimmart == "DIREKT": 
                    NPD_1 = subsub.attrib.get("Stimmen")
                if stimmart == "LISTE": 
                    NPD_2 = subsub.attrib.get("Stimmen")
            elif position == "7":
                stimmart = subsub.attrib.get("Stimmart")
                if stimmart == "DIREKT": 
                    FDP_1 = subsub.attrib.get("Stimmen")
                if stimmart == "LISTE": 
                    FDP_2 = subsub.attrib.get("Stimmen")
            elif position == "8":
                stimmart = subsub.attrib.get("Stimmart")
                if stimmart == "DIREKT": 
                    FREIE_1 = subsub.attrib.get("Stimmen")
                if stimmart == "LISTE": 
                    FREIE_2 = subsub.attrib.get("Stimmen")
            elif position == "9":
                stimmart = subsub.attrib.get("Stimmart")
                if stimmart == "DIREKT": 
                    Tierschutzpartei_1 = subsub.attrib.get("Stimmen")
                if stimmart == "LISTE": 
                    Tierschutzpartei_2 = subsub.attrib.get("Stimmen")
            elif position == "10":
                stimmart = subsub.attrib.get("Stimmart")
                if stimmart == "DIREKT": 
                    PIRATEN_1 = subsub.attrib.get("Stimmen")
                if stimmart == "LISTE": 
                    PIRATEN_2 = subsub.attrib.get("Stimmen")
            elif position == "11":
                stimmart = subsub.attrib.get("Stimmart")
                if stimmart == "DIREKT": 
                    PARTEI_1 = subsub.attrib.get("Stimmen")
                if stimmart == "LISTE": 
                    PARTEI_2 = subsub.attrib.get("Stimmen")
            elif position == "12":
                stimmart = subsub.attrib.get("Stimmart")
                if stimmart == "DIREKT": 
                    BüSo_1 = subsub.attrib.get("Stimmen")
                if stimmart == "LISTE": 
                    BüSo_2 = subsub.attrib.get("Stimmen")
            elif position == "13":
                stimmart = subsub.attrib.get("Stimmart")
                if stimmart == "DIREKT": 
                    ADPM_1 = subsub.attrib.get("Stimmen")
                if stimmart == "LISTE": 
                    ADPM_2 = subsub.attrib.get("Stimmen")
            elif position == "14":
                stimmart = subsub.attrib.get("Stimmart")
                if stimmart == "DIREKT": 
                    Blaue_1 = subsub.attrib.get("Stimmen")
                if stimmart == "LISTE": 
                    Blaue_2 = subsub.attrib.get("Stimmen")
            elif position == "15":
                stimmart = subsub.attrib.get("Stimmart")
                if stimmart == "DIREKT": 
                    KPD_1 = subsub.attrib.get("Stimmen")
                if stimmart == "LISTE": 
                    KPD_2 = subsub.attrib.get("Stimmen")
            elif position == "16":
                stimmart = subsub.attrib.get("Stimmart")
                if stimmart == "DIREKT": 
                    ÖDP_1 = subsub.attrib.get("Stimmen")
                if stimmart == "LISTE": 
                    ÖDP_2 = subsub.attrib.get("Stimmen")
            elif position == "17":
                stimmart = subsub.attrib.get("Stimmart")
                if stimmart == "DIREKT": 
                    Humanisten_1 = subsub.attrib.get("Stimmen")
                if stimmart == "LISTE": 
                    Humanisten_2 = subsub.attrib.get("Stimmen")
            elif position == "18":
                stimmart = subsub.attrib.get("Stimmart")
                if stimmart == "DIREKT": 
                    PDV_1 = subsub.attrib.get("Stimmen")
                if stimmart == "LISTE": 
                    PDV_2 = subsub.attrib.get("Stimmen")
            elif position == "19":
                stimmart = subsub.attrib.get("Stimmart")
                if stimmart == "DIREKT": 
                    Gesundheitsforschung_1 = subsub.attrib.get("Stimmen")
                if stimmart == "LISTE": 
                    Gesundheitsforschung_2 = subsub.attrib.get("Stimmen")
                    
                    
                    
    df_ergebnisse = df_ergebnisse.append(pd.Series([
        kreis, gemeinde, wahlberechtigte, wähler, ungültige_1, ungültige_2, gültige_1, gültige_2, 
        CDU_1, LINKE_1, SPD_1, AfD_1, GRÜNE_1, NPD_1, FDP_1, FREIE_1, Tierschutzpartei_1, PIRATEN_1, 
        PARTEI_1, BüSo_1, ADPM_1, Blaue_1, KPD_1, ÖDP_1, Humanisten_1, PDV_1, Gesundheitsforschung_1, 
        CDU_2, LINKE_2, SPD_2, AfD_2, GRÜNE_2, NPD_2, FDP_2, FREIE_2, Tierschutzpartei_2, PIRATEN_2, 
        PARTEI_2, BüSo_2, ADPM_2, Blaue_2, KPD_2, ÖDP_2, Humanisten_2, PDV_2, Gesundheitsforschung_2         
    ], index=columns), ignore_index=True)

# %%
# alle Ergebnisse in int konvertieren
cols=[i for i in df_ergebnisse.columns]
for col in cols:
    df_ergebnisse[col]=pd.to_numeric(df_ergebnisse[col])
    df_ergebnisse[col]= df_ergebnisse[col].fillna(0).astype(int)

# %%
df_ergebnisse.tail()
# Out:
#      WK-Nr       AGS  Wahlberechtigte  Wähler  ungültige_1  ungültige_2  \
# 425     60  14626390             4348    2294           65           75
# 426     60  14626400             3997    2384           74           66
# 427     60  14626430             1185     555           13           18
# 428     60  14626530             3120    1895           51           22
# 429     60  14626610            21048   13728          355          324
#
#      gültige_1  gültige_2  CDU_1  LINKE_1  ...  PIRATEN_2  Die PARTEI_2  \
# 425       2229       2219    571      271  ...          3           269
# 426       2310       2318    571      278  ...          4           298
# 427        542        537    143       63  ...          0            54
# 428       1844       1873    458      231  ...          9           222
# 429      13373      13404   3359     1695  ...         22          1379
#
#      BüSo_2  ADPM_2  Blaue #TeamPetry_2  KPD_2  ÖDP_2  Die Humanisten_2  \
# 425       0       0                   0      0      0                 0
# 426       3      13                   0      0      0                 0
# 427       1       6                   1     11      0                 0
# 428       0       0                   0      0      0                 0
# 429      35     165                  21     29      0                 0
#
#      PDV_2  Gesundheitsforschung_2
# 425      0                       0
# 426      0                       0
# 427      0                       0
# 428      0                       0
# 429      0                       0
#
# [5 rows x 46 columns]

# %%
# WK in Großstädten einmal zusammenfassen
df_leipzig = df_ergebnisse[(df_ergebnisse["AGS"]>147130000) & (df_ergebnisse["AGS"]<147130010)]
df_dresden = df_ergebnisse[(df_ergebnisse["AGS"]>146120000) & (df_ergebnisse["AGS"]<146120010)]
df_zwickau = df_ergebnisse[(df_ergebnisse["AGS"]>145243300) & (df_ergebnisse["AGS"]<145243303)]
df_chemnitz = df_ergebnisse[(df_ergebnisse["AGS"]>145110000) & (df_ergebnisse["AGS"]<145110005)]

# %%
df_leipzig["AGS"] = 147130000
df_dresden["AGS"] = 146120000
df_zwickau["AGS"] = 145243300
df_chemnitz["AGS"] = 145110000
# Out:
# C:\Users\Felix\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\Felix\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\Felix\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\Felix\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
group_le = df_leipzig.groupby("AGS").sum()
group_dd = df_dresden.groupby("AGS").sum()
group_zw = df_zwickau.groupby("AGS").sum()
group_ch = df_chemnitz.groupby("AGS").sum()

# %%
group_le.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1 entries, 147130000 to 147130000
# Data columns (total 45 columns):
# WK-Nr                     1 non-null int32
# Wahlberechtigte           1 non-null int32
# Wähler                    1 non-null int32
# ungültige_1               1 non-null int32
# ungültige_2               1 non-null int32
# gültige_1                 1 non-null int32
# gültige_2                 1 non-null int32
# CDU_1                     1 non-null int32
# LINKE_1                   1 non-null int32
# SPD_1                     1 non-null int32
# AfD_1                     1 non-null int32
# GRÜNE_1                   1 non-null int32
# NPD_1                     1 non-null int32
# FDP_1                     1 non-null int32
# FREIE WÄHLER_1            1 non-null int32
# Tierschutzpartei_1        1 non-null int32
# PIRATEN_1                 1 non-null int32
# Die PARTEI_1              1 non-null int32
# BüSo_1                    1 non-null int32
# ADPM_1                    1 non-null int32
# Blaue #TeamPetry_1        1 non-null int32
# KPD_1                     1 non-null int32
# ÖDP_1                     1 non-null int32
# Die Humanisten_1          1 non-null int32
# PDV_1                     1 non-null int32
# Gesundheitsforschung_1    1 non-null int32
# CDU_2                     1 non-null int32
# LINKE_2                   1 non-null int32
# SPD_2                     1 non-null int32
# AfD_2                     1 non-null int32
# GRÜNE_2                   1 non-null int32
# NPD_2                     1 non-null int32
# FDP_2                     1 non-null int32
# FREIE WÄHLER_2            1 non-null int32
# Tierschutzpartei_2        1 non-null int32
# PIRATEN_2                 1 non-null int32
# Die PARTEI_2              1 non-null int32
# BüSo_2                    1 non-null int32
# ADPM_2                    1 non-null int32
# Blaue #TeamPetry_2        1 non-null int32
# KPD_2                     1 non-null int32
# ÖDP_2                     1 non-null int32
# Die Humanisten_2          1 non-null int32
# PDV_2                     1 non-null int32
# Gesundheitsforschung_2    1 non-null int32
# dtypes: int32(45)
# memory usage: 188.0 bytes

# %%
df_ergebnisse = pd.concat([df_ergebnisse, group_le, group_dd, group_zw, group_ch], ignore_index=True, sort=False )
# Out:
# C:\Users\Felix\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.

# %%
df_ergebnisse.tail()
# Out:
#      ADPM_1  ADPM_2         AGS  AfD_1  AfD_2  Blaue #TeamPetry_1  \
# 429       0     165  14626610.0   3427   3256                   0
# 430       0     988         NaN  69861  70100                 170
# 431       0    1012         NaN  64086  64116                   0
# 432       0     513         NaN  11241  11278                   0
# 433       0     620         NaN  29657  29628                   0
#
#      Blaue #TeamPetry_2  BüSo_1  BüSo_2  CDU_1  ...  Tierschutzpartei_2  \
# 429                  21       0      35   3359  ...                  28
# 430                 675    3244     191  69745  ...                 609
# 431                 509    1107     129  64460  ...                 744
# 432                 230       0      48  11213  ...                 145
# 433                 504       0     248  29244  ...                 245
#
#      WK-Nr  Wahlberechtigte  Wähler  gültige_1  gültige_2  ungültige_1  \
# 429     60            21048   13728      13373      13404          355
# 430    210           454193  287305     280075     280062         7230
# 431    308           427120  263773     257208     257500         6565
# 432     13            72960   46167      45055      44976         1112
# 433     33           192593  121142     118178     118145         2964
#
#      ungültige_2  ÖDP_1  ÖDP_2
# 429          324      0      0
# 430         7243      0     15
# 431         6273      0      0
# 432         1191      0     11
# 433         2997      0      0
#
# [5 rows x 46 columns]
